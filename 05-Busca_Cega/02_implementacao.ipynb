# %% [markdown]
# # Busca Cega
#
# Abordagem de busca que não considera nenhuma informação sobre qual sucessor é mais promissor para atingir uma meta (objetivo)
# ###### Passos
# - Formular objetivo
# - Formular a busca
# - Executar

# %% [markdown]
# ### Modelando o problema
# - Sliding Puzzle
# <img src="images/sliding_puzzle.gif" width="250" align="center">

# %%
import numpy as np

class SlidingPuzzle():
    def __init__(self, num_blocos):
        '''
        Construtor
        Args:
            - num_blocos: numero de blocos por linha e coluna, valor inteiro (Ex: 3 significa 3 linhas e 3 colunas)
        '''
        self.num_blocos = num_blocos

    def _encontra_posicao(self, estado, elemento):
        '''
        Varre todo o tabuleiro (estado) e verifica em qual posição 'elemento' está
        Args:
            - estado: matriz contendo o estado do tabuleiro
            - elemento: elemento a ser buscado na matriz
        Return:
            - Retorna a linha e coluna onde o elemento se encontra
        '''
        for i in range(self.num_blocos):
            for j in range(self.num_blocos):
                if estado[i, j] == elemento:
                    return i, j
        return None, None

    def verifica_estados(self, atual, objetivo):
        '''
        Verifica se o estado atual é o objetivo da busca
        Args:
            - atual: matriz que descreve o estado atual
            - objetivo: matriz que descreve o estado objetivo
        Return:
            - booleano dizendo se o estado atual é ou não o objetivo
        '''
        flag = True
        for i in range(self.num_blocos):
            for j in range(self.num_blocos):
                if atual[i, j] != objetivo[i, j]:
                    flag = False
                    break

        return flag

    def expande_estados(self, atual):
        '''
        Dado o estado atual, realiza a expansão de estados
        Args:
            - atual: matriz que descreve o estado atual
        Return:
            - lista com os novos estados após a expansão
        '''
        
        novos_estados = []
        linha, coluna = self._encontra_posicao(atual, 0)

        # Cima
        if linha > 0:
            novo_estado = np.copy(atual)
            nova_linha = linha - 1

            bloco_alvo = novo_estado[nova_linha, coluna]
            novo_estado[nova_linha, coluna] = 0
            novo_estado[linha, coluna] = bloco_alvo

            novos_estados.append(novo_estado)

        # Baixo
        if linha < self.num_blocos - 1:
            novo_estado = np.copy(atual)
            nova_linha = linha + 1

            bloco_alvo = novo_estado[nova_linha, coluna]
            novo_estado[nova_linha, coluna] = 0
            novo_estado[linha, coluna] = bloco_alvo

            novos_estados.append(novo_estado)


        # Esquerda
        if coluna > 0:
            novo_estado = np.copy(atual)
            nova_coluna = coluna - 1

            bloco_alvo = novo_estado[linha, nova_coluna]
            novo_estado[linha, nova_coluna] = 0
            novo_estado[linha, coluna] = bloco_alvo

            novos_estados.append(novo_estado)

        # Direita
        if coluna < self.num_blocos - 1:
            novo_estado = np.copy(atual)
            nova_coluna = coluna + 1

            bloco_alvo = novo_estado[linha, nova_coluna]
            novo_estado[linha, nova_coluna] = 0
            novo_estado[linha, coluna] = bloco_alvo

            novos_estados.append(novo_estado)

        return novos_estados

# %% [markdown]
# ### Formulando Busca

# %% [markdown]
# #### Busca em largura (BrFS– Breadth-first search)
#
# Realiza a busca em nível. Imagine uma árvore de estados, nela a busca é realizada sequencialmente em cada nó do mesmo nível
#
# <img src="images/bfs.gif" width="250" align="center">

# %%
from queue import Queue
# Classe 
class BreadthFirstSearch():
    
    def __init__(self, problema):
        self.problema = problema
        
    def _verifica_visitado(self, estado, estados_visitados):
        for i in estados_visitados:
            if self.problema.verifica_estados(i, estado):
                return True
        return False
        
    def busca(self, inicio, fim):
        fila = Queue()
        fila.put(inicio)
        
        solucao_encontrada = False
        estados_visitados = []
        cont_estados = 0
        
        while not fila.empty():
            atual = fila.get()
            estados_visitados.append(atual)
            
            if self.problema.verifica_estados(atual, fim):
                solucao_encontrada = True
                break
                
            else:
                cont_estados += 1
                print(f"Visitando #{cont_estados}")
                novos_estados = self.problema.expande_estados(atual)
                for i in novos_estados:
                    if not self._verifica_visitado(i, estados_visitados):
                        fila.put(i)
                        
        return solucao_encontrada, estados_visitados, cont_estados
            
## Construtor 
## Verificar se estado já foi visitado
## Busca
### Enquanto houver elementos na fila
#### Verificar objetivo
#### Expandir estados
#### Expandir estados

# %% [markdown]
# #### Busca em profundidade (DFS – Depth-first search)
#
# Realiza a busca por ramo. Imagine uma árvore de estados, nela a busca é realizada sequencialmente em cada ramo, e só após completá-lo, busca no ramo vizinho.
#
# <img src="images/dfs.gif" width="250" align="center">

# %%
from queue import LifoQueue

class DepthFirstSearch():
    def __init__(self, problema):
        '''
        Construtor
        Args:
            - problema: objeto do problema a ser solucionado
        '''
        self.problema = problema
        
    def _verifica_visitado(self, estado, estados_visitados):
        '''
        Verifica se 'estado' está na lista de estados visitados
        Args:
            - estado: estado qualquer do tabuleiro
            - estados_visitados: lista com todos os estados já visitados
        Return:
            - booleano dizendo se o estado foi visitado ou não
        '''
        for i in estados_visitados:
            if self.problema.verifica_estados(i, estado):
                return True
        return False
    
    def busca(self, inicio, fim):
        '''
        Realiza a busca DFS, armazenando os estados em uma PILHA
        Args:
            - inicio: estado inicial do problema
            - fim: estado objetivo
        Return:
            - booleano se a solução foi encontrada, lista dos estados visitados, quantidade de estados visitados
        '''
        pilha = LifoQueue()
        pilha.put(inicio)
        
        solucao_encontrada = False
        estados_visitados = []
        cont_estados = 0
        
        while not pilha.empty():
            atual = pilha.get()
            estados_visitados.append(atual)
            
            if self.problema.verifica_estados(atual, fim):
                solucao_encontrada = True
                break
                
            else:
                cont_estados += 1
                print(f"Visitando #{cont_estados}")
                novos_estados = self.problema.expande_estados(atual)
                for i in novos_estados:
                    if not self._verifica_visitado(i, estados_visitados):
                        print(i)
                        pilha.put(i)
                        
        return solucao_encontrada, estados_visitados, cont_estados
    
## Construtor 
## Verificar se estado já foi visitado
## Busca
### Enquanto houver elementos na fila
#### Verificar objetivo
#### Expandir estados
#### Expandir estados

# %% [markdown]
# ### Executando

# %%
# Pacote auxiliar para o cálculo do tempo
from time import time

# Criando objeto do problema
problema = SlidingPuzzle(3)

# Criando Matriz inicial e matriz alvo
start = np.matrix([[1,0,2],[8,4,3],[7,6,5]])
target = np.matrix([[1,2,3],[8,0,4],[7,6,5]])

# Mostrando informações iniciais
print(f"Initial state: \n{start}")
print("*"*15)
print(f"Target state: \n{target}")
print("*"*15)
# Out:
# Initial state:
# [[1 0 2]
#  [8 4 3]
#  [7 6 5]]
# ***************
# Target state:
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
# ***************

# %% [markdown]
# #### BFS

# %%
# Instanciando a classe BreadthFirstSearch
bfs_solver = BreadthFirstSearch(problema)

# Resolvendo o problema com BFS
solucao_encontrada, estados_visitados, cont_estados = bfs_solver.busca(start, target)

# Imprimindo os resultados
if solucao_encontrada:
    print("Solução encontrada!")
    print(f"Estado final: \n{solucao_encontrada}")
else:
    print("Solução não encontrada.")

print(f"Total de estados visitados: {len(estados_visitados)}")
print(f"Número de passos até a solução: {cont_estados}")
# Out:
# Visitando #1
# Visitando #2
# Visitando #3
# Visitando #4
# Visitando #5
# Visitando #6
# Visitando #7
# Visitando #8
# Visitando #9
# Visitando #10
# Visitando #11
# Visitando #12
# Visitando #13
# Visitando #14
# Visitando #15
# Visitando #16
# Visitando #17
# Visitando #18
# Solução encontrada!
# Estado final:
# True
# Total de estados visitados: 19
# Número de passos até a solução: 18

# %% [markdown]
# #### DFS

# %%
# Instanciando a classe DepthFirstSearch
dfs_solver = DepthFirstSearch(problema)

# Resolvendo o problema com DFS
solucao_encontrada_dfs, estados_visitados_dfs, cont_estados_dfs = dfs_solver.busca(start, target)

# Imprimindo os resultados do DFS
if solucao_encontrada_dfs:
    print("Solução encontrada pelo DFS!")
    print(f"Estado final: \n{solucao_encontrada_dfs}")
else:
    print("Solução não encontrada pelo DFS.")

print(f"Total de estados visitados pelo DFS: {len(estados_visitados_dfs)}")
print(f"Número de passos até a solução pelo DFS: {cont_estados_dfs}")
# Out:
# Visitando #1
# [[1 4 2]
#  [8 0 3]
#  [7 6 5]]
# [[0 1 2]
#  [8 4 3]
#  [7 6 5]]
# [[1 2 0]
#  [8 4 3]
#  [7 6 5]]
# Visitando #2
# [[1 2 3]
#  [8 4 0]
#  [7 6 5]]
# Visitando #3
# [[1 2 3]
#  [8 4 5]
#  [7 6 0]]
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
# Solução encontrada pelo DFS!
# Estado final:
# True
# Total de estados visitados pelo DFS: 4
# Número de passos até a solução pelo DFS: 3

# %% [markdown]
# #### Resultados

# %% [markdown]
# # Exercícios
#
# 1. Alterar a matriz inicial de posições para a apresentada na imagem abaixo e avaliar a performance das duas abordagens de busca cega
#
# <img src="images/exercicio.png" width="250" align="center">

# %%
target = np.matrix([[2, 8,3],[1,6,4],[7,0,5]])

# Instanciando a classe BreadthFirstSearch
bfs_solver = BreadthFirstSearch(problema)

# Resolvendo o problema com BFS
solucao_encontrada, estados_visitados, cont_estados = bfs_solver.busca(start, target)

# Imprimindo os resultados
if solucao_encontrada:
    print("Solução encontrada!")
    print(f"Estado final: \n{solucao_encontrada}")
else:
    print("Solução não encontrada.")

print(f"Total de estados visitados: {len(estados_visitados)}")
print(f"Número de passos até a solução: {cont_estados}")


# usando DFS
dfs_solver = DepthFirstSearch(problema)

# Resolvendo o problema com DFS
solucao_encontrada_dfs, estados_visitados_dfs, cont_estados_dfs = dfs_solver.busca(start, target)

# Imprimindo os resultados do DFS
if solucao_encontrada_dfs:
    print("Solução encontrada pelo DFS!")
    print(f"Estado final: \n{solucao_encontrada_dfs}")
else:
    print("Solução não encontrada pelo DFS.")

print(f"Total de estados visitados pelo DFS: {len(estados_visitados_dfs)}")
print(f"Número de passos até a solução pelo DFS: {cont_estados_dfs}")

# Comparação
print(f"Comparação entre BFS e DFS:")
print(f"BFS: {cont_estados} passos")
print(f"DFS: {cont_estados_dfs} passos")
print(f"BFS: {len(estados_visitados)} estados visitados")
print(f"DFS: {len(estados_visitados_dfs)} estados visitados")
# Out:
# Visitando #1
# Visitando #2
# Visitando #3
# Visitando #4
# Visitando #5
# Visitando #6
# Visitando #7
# Visitando #8
# Visitando #9
# Visitando #10
# Visitando #11
# Visitando #12
# Visitando #13
# Visitando #14
# Visitando #15
# Visitando #16
# Visitando #17
# Visitando #18
# Visitando #19
# Visitando #20
# Visitando #21
# Visitando #22
# Visitando #23
# Visitando #24
# Visitando #25
# Visitando #26
# Visitando #27
# Visitando #28
# Visitando #29
# Visitando #30
# Visitando #31
# Visitando #32
# Visitando #33
# Visitando #34
# Visitando #35
# Visitando #36
# Visitando #37
# Visitando #38
# Visitando #39
# Visitando #40
# Visitando #41
# Visitando #42
# Visitando #43
# Visitando #44
# Visitando #45
# Visitando #46
# Visitando #47
# Visitando #48
# Visitando #49
# Visitando #50
# Visitando #51
# Visitando #52
# Visitando #53
# Visitando #54
# Visitando #55
# Visitando #56
# Visitando #57
# Visitando #58
# Visitando #59
# Visitando #60
# Visitando #61
# Visitando #62
# Visitando #63
# Visitando #64
# Visitando #65
# Visitando #66
# Visitando #67
# Visitando #68
# Visitando #69
# Visitando #70
# Visitando #71
# Visitando #72
# Visitando #73
# Visitando #74
# Visitando #75
# Visitando #76
# Visitando #77
# Visitando #78
# Visitando #79
# Visitando #80
# Visitando #81
# Visitando #82
# Visitando #83
# Visitando #84
# Visitando #85
# Visitando #86
# Visitando #87
# Visitando #88
# Visitando #89
# Visitando #90
# Visitando #91
# Visitando #92
# Visitando #93
# Visitando #94
# Visitando #95
# Visitando #96
# Visitando #97
# Visitando #98
# Visitando #99
# Visitando #100
# Visitando #101
# Visitando #102
# Visitando #103
# Visitando #104
# Visitando #105
# Visitando #106
# Visitando #107
# Visitando #108
# Visitando #109
# Visitando #110
# Visitando #111
# Visitando #112
# Visitando #113
# Visitando #114
# Visitando #115
# Visitando #116
# Visitando #117
# Visitando #118
# Visitando #119
# Visitando #120
# Visitando #121
# Visitando #122
# Visitando #123
# Visitando #124
# Visitando #125
# Visitando #126
# Visitando #127
# Visitando #128
# Visitando #129
# Visitando #130
# Visitando #131
# Visitando #132
# Visitando #133
# Visitando #134
# Visitando #135
# Visitando #136
# Visitando #137
# Visitando #138
# Visitando #139
# Visitando #140
# Visitando #141
# Visitando #142
# Visitando #143
# Visitando #144
# Visitando #145
# Visitando #146
# Visitando #147
# Visitando #148
# Visitando #149
# Visitando #150
# Visitando #151
# Visitando #152
# Visitando #153
# Visitando #154
# Visitando #155
# Visitando #156
# Visitando #157
# Visitando #158
# Visitando #159
# Visitando #160
# Visitando #161
# Visitando #162
# Visitando #163
# Visitando #164
# Visitando #165
# Visitando #166
# Visitando #167
# Visitando #168
# Visitando #169
# Visitando #170
# Visitando #171
# Visitando #172
# Visitando #173
# Visitando #174
# Visitando #175
# Visitando #176
# Visitando #177
# Visitando #178
# Visitando #179
# Visitando #180
# Visitando #181
# Visitando #182
# Visitando #183
# Visitando #184
# Visitando #185
# Visitando #186
# Visitando #187
# Visitando #188
# Visitando #189
# Visitando #190
# Visitando #191
# Visitando #192
# Visitando #193
# Visitando #194
# Visitando #195
# Visitando #196
# Visitando #197
# Visitando #198
# Visitando #199
# Visitando #200
# Visitando #201
# Visitando #202
# Visitando #203
# Visitando #204
# Visitando #205
# Visitando #206
# Visitando #207
# Visitando #208
# Visitando #209
# Visitando #210
# Visitando #211
# Visitando #212
# Visitando #213
# Visitando #214
# Visitando #215
# Visitando #216
# Visitando #217
# Visitando #218
# Visitando #219
# Visitando #220
# Visitando #221
# Visitando #222
# Visitando #223
# Visitando #224
# Visitando #225
# Visitando #226
# Visitando #227
# Visitando #228
# Visitando #229
# Visitando #230
# Visitando #231
# Visitando #232
# Visitando #233
# Visitando #234
# Visitando #235
# Visitando #236
# Visitando #237
# Visitando #238
# Visitando #239
# Visitando #240
# Visitando #241
# Visitando #242
# Visitando #243
# Visitando #244
# Visitando #245
# Visitando #246
# Visitando #247
# Visitando #248
# Visitando #249
# Visitando #250
# Visitando #251
# Visitando #252
# Visitando #253
# Visitando #254
# Visitando #255
# Visitando #256
# Visitando #257
# Visitando #258
# Visitando #259
# Visitando #260
# Visitando #261
# Visitando #262
# Visitando #263
# Visitando #264
# Visitando #265
# Visitando #266
# Visitando #267
# Visitando #268
# Visitando #269
# Visitando #270
# Visitando #271
# Visitando #272
# Visitando #273
# Visitando #274
# Visitando #275
# Visitando #276
# Visitando #277
# Visitando #278
# Visitando #279
# Visitando #280
# Visitando #281
# Visitando #282
# Visitando #283
# Visitando #284
# Visitando #285
# Visitando #286
# Visitando #287
# Visitando #288
# Visitando #289
# Visitando #290
# Visitando #291
# Visitando #292
# Visitando #293
# Visitando #294
# Visitando #295
# Visitando #296
# Visitando #297
# Solução encontrada!
# Estado final:
# True
# Total de estados visitados: 298
# Número de passos até a solução: 297
# Visitando #1
# [[1 4 2]
#  [8 0 3]
#  [7 6 5]]
# [[0 1 2]
#  [8 4 3]
#  [7 6 5]]
# [[1 2 0]
#  [8 4 3]
#  [7 6 5]]
# Visitando #2
# [[1 2 3]
#  [8 4 0]
#  [7 6 5]]
# Visitando #3
# [[1 2 3]
#  [8 4 5]
#  [7 6 0]]
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
# Visitando #4
# [[1 0 3]
#  [8 2 4]
#  [7 6 5]]
# [[1 2 3]
#  [8 6 4]
#  [7 0 5]]
# [[1 2 3]
#  [0 8 4]
#  [7 6 5]]
# Visitando #5
# [[0 2 3]
#  [1 8 4]
#  [7 6 5]]
# [[1 2 3]
#  [7 8 4]
#  [0 6 5]]
# Visitando #6
# [[1 2 3]
#  [7 8 4]
#  [6 0 5]]
# Visitando #7
# [[1 2 3]
#  [7 0 4]
#  [6 8 5]]
# [[1 2 3]
#  [7 8 4]
#  [6 5 0]]
# Visitando #8
# [[1 2 3]
#  [7 8 0]
#  [6 5 4]]
# Visitando #9
# [[1 2 0]
#  [7 8 3]
#  [6 5 4]]
# [[1 2 3]
#  [7 0 8]
#  [6 5 4]]
# Visitando #10
# [[1 0 3]
#  [7 2 8]
#  [6 5 4]]
# [[1 2 3]
#  [7 5 8]
#  [6 0 4]]
# [[1 2 3]
#  [0 7 8]
#  [6 5 4]]
# Visitando #11
# [[0 2 3]
#  [1 7 8]
#  [6 5 4]]
# [[1 2 3]
#  [6 7 8]
#  [0 5 4]]
# Visitando #12
# [[1 2 3]
#  [6 7 8]
#  [5 0 4]]
# Visitando #13
# [[1 2 3]
#  [6 0 8]
#  [5 7 4]]
# [[1 2 3]
#  [6 7 8]
#  [5 4 0]]
# Visitando #14
# [[1 2 3]
#  [6 7 0]
#  [5 4 8]]
# Visitando #15
# [[1 2 0]
#  [6 7 3]
#  [5 4 8]]
# [[1 2 3]
#  [6 0 7]
#  [5 4 8]]
# Visitando #16
# [[1 0 3]
#  [6 2 7]
#  [5 4 8]]
# [[1 2 3]
#  [6 4 7]
#  [5 0 8]]
# [[1 2 3]
#  [0 6 7]
#  [5 4 8]]
# Visitando #17
# [[0 2 3]
#  [1 6 7]
#  [5 4 8]]
# [[1 2 3]
#  [5 6 7]
#  [0 4 8]]
# Visitando #18
# [[1 2 3]
#  [5 6 7]
#  [4 0 8]]
# Visitando #19
# [[1 2 3]
#  [5 0 7]
#  [4 6 8]]
# [[1 2 3]
#  [5 6 7]
#  [4 8 0]]
# Visitando #20
# [[1 2 3]
#  [5 6 0]
#  [4 8 7]]
# Visitando #21
# [[1 2 0]
#  [5 6 3]
#  [4 8 7]]
# [[1 2 3]
#  [5 0 6]
#  [4 8 7]]
# Visitando #22
# [[1 0 3]
#  [5 2 6]
#  [4 8 7]]
# [[1 2 3]
#  [5 8 6]
#  [4 0 7]]
# [[1 2 3]
#  [0 5 6]
#  [4 8 7]]
# Visitando #23
# [[0 2 3]
#  [1 5 6]
#  [4 8 7]]
# [[1 2 3]
#  [4 5 6]
#  [0 8 7]]
# Visitando #24
# [[1 2 3]
#  [4 5 6]
#  [8 0 7]]
# Visitando #25
# [[1 2 3]
#  [4 0 6]
#  [8 5 7]]
# [[1 2 3]
#  [4 5 6]
#  [8 7 0]]
# Visitando #26
# [[1 2 3]
#  [4 5 0]
#  [8 7 6]]
# Visitando #27
# [[1 2 0]
#  [4 5 3]
#  [8 7 6]]
# [[1 2 3]
#  [4 0 5]
#  [8 7 6]]
# Visitando #28
# [[1 0 3]
#  [4 2 5]
#  [8 7 6]]
# [[1 2 3]
#  [4 7 5]
#  [8 0 6]]
# [[1 2 3]
#  [0 4 5]
#  [8 7 6]]
# Visitando #29
# [[0 2 3]
#  [1 4 5]
#  [8 7 6]]
# [[1 2 3]
#  [8 4 5]
#  [0 7 6]]
# Visitando #30
# [[1 2 3]
#  [8 4 5]
#  [7 0 6]]
# Visitando #31
# [[1 2 3]
#  [8 0 5]
#  [7 4 6]]
# [[1 2 3]
#  [8 4 5]
#  [7 6 0]]
# Visitando #32
# Visitando #33
# [[1 0 3]
#  [8 2 5]
#  [7 4 6]]
# [[1 2 3]
#  [0 8 5]
#  [7 4 6]]
# [[1 2 3]
#  [8 5 0]
#  [7 4 6]]
# Visitando #34
# [[1 2 0]
#  [8 5 3]
#  [7 4 6]]
# [[1 2 3]
#  [8 5 6]
#  [7 4 0]]
# Visitando #35
# [[1 2 3]
#  [8 5 6]
#  [7 0 4]]
# Visitando #36
# [[1 2 3]
#  [8 0 6]
#  [7 5 4]]
# [[1 2 3]
#  [8 5 6]
#  [0 7 4]]
# Visitando #37
# [[1 2 3]
#  [0 5 6]
#  [8 7 4]]
# Visitando #38
# [[0 2 3]
#  [1 5 6]
#  [8 7 4]]
# [[1 2 3]
#  [5 0 6]
#  [8 7 4]]
# Visitando #39
# [[1 0 3]
#  [5 2 6]
#  [8 7 4]]
# [[1 2 3]
#  [5 7 6]
#  [8 0 4]]
# [[1 2 3]
#  [5 6 0]
#  [8 7 4]]
# Visitando #40
# [[1 2 0]
#  [5 6 3]
#  [8 7 4]]
# [[1 2 3]
#  [5 6 4]
#  [8 7 0]]
# Visitando #41
# [[1 2 3]
#  [5 6 4]
#  [8 0 7]]
# Visitando #42
# [[1 2 3]
#  [5 0 4]
#  [8 6 7]]
# [[1 2 3]
#  [5 6 4]
#  [0 8 7]]
# Visitando #43
# [[1 2 3]
#  [0 6 4]
#  [5 8 7]]
# Visitando #44
# [[0 2 3]
#  [1 6 4]
#  [5 8 7]]
# [[1 2 3]
#  [6 0 4]
#  [5 8 7]]
# Visitando #45
# [[1 0 3]
#  [6 2 4]
#  [5 8 7]]
# [[1 2 3]
#  [6 8 4]
#  [5 0 7]]
# [[1 2 3]
#  [6 4 0]
#  [5 8 7]]
# Visitando #46
# [[1 2 0]
#  [6 4 3]
#  [5 8 7]]
# [[1 2 3]
#  [6 4 7]
#  [5 8 0]]
# Visitando #47
# [[1 2 3]
#  [6 4 7]
#  [5 0 8]]
# Visitando #48
# [[1 2 3]
#  [6 4 7]
#  [0 5 8]]
# Visitando #49
# [[1 2 3]
#  [0 4 7]
#  [6 5 8]]
# Visitando #50
# [[0 2 3]
#  [1 4 7]
#  [6 5 8]]
# [[1 2 3]
#  [4 0 7]
#  [6 5 8]]
# Visitando #51
# [[1 0 3]
#  [4 2 7]
#  [6 5 8]]
# [[1 2 3]
#  [4 5 7]
#  [6 0 8]]
# [[1 2 3]
#  [4 7 0]
#  [6 5 8]]
# Visitando #52
# [[1 2 0]
#  [4 7 3]
#  [6 5 8]]
# [[1 2 3]
#  [4 7 8]
#  [6 5 0]]
# Visitando #53
# [[1 2 3]
#  [4 7 8]
#  [6 0 5]]
# Visitando #54
# [[1 2 3]
#  [4 0 8]
#  [6 7 5]]
# [[1 2 3]
#  [4 7 8]
#  [0 6 5]]
# Visitando #55
# [[1 2 3]
#  [0 7 8]
#  [4 6 5]]
# Visitando #56
# [[0 2 3]
#  [1 7 8]
#  [4 6 5]]
# [[1 2 3]
#  [7 0 8]
#  [4 6 5]]
# Visitando #57
# [[1 0 3]
#  [7 2 8]
#  [4 6 5]]
# [[1 2 3]
#  [7 6 8]
#  [4 0 5]]
# [[1 2 3]
#  [7 8 0]
#  [4 6 5]]
# Visitando #58
# [[1 2 0]
#  [7 8 3]
#  [4 6 5]]
# [[1 2 3]
#  [7 8 5]
#  [4 6 0]]
# Visitando #59
# [[1 2 3]
#  [7 8 5]
#  [4 0 6]]
# Visitando #60
# [[1 2 3]
#  [7 0 5]
#  [4 8 6]]
# [[1 2 3]
#  [7 8 5]
#  [0 4 6]]
# Visitando #61
# [[1 2 3]
#  [0 8 5]
#  [7 4 6]]
# Visitando #62
# [[0 2 3]
#  [1 8 5]
#  [7 4 6]]
# Visitando #63
# [[2 0 3]
#  [1 8 5]
#  [7 4 6]]
# Visitando #64
# [[2 8 3]
#  [1 0 5]
#  [7 4 6]]
# [[2 3 0]
#  [1 8 5]
#  [7 4 6]]
# Visitando #65
# [[2 3 5]
#  [1 8 0]
#  [7 4 6]]
# Visitando #66
# [[2 3 5]
#  [1 8 6]
#  [7 4 0]]
# [[2 3 5]
#  [1 0 8]
#  [7 4 6]]
# Visitando #67
# [[2 0 5]
#  [1 3 8]
#  [7 4 6]]
# [[2 3 5]
#  [1 4 8]
#  [7 0 6]]
# [[2 3 5]
#  [0 1 8]
#  [7 4 6]]
# Visitando #68
# [[0 3 5]
#  [2 1 8]
#  [7 4 6]]
# [[2 3 5]
#  [7 1 8]
#  [0 4 6]]
# Visitando #69
# [[2 3 5]
#  [7 1 8]
#  [4 0 6]]
# Visitando #70
# [[2 3 5]
#  [7 0 8]
#  [4 1 6]]
# [[2 3 5]
#  [7 1 8]
#  [4 6 0]]
# Visitando #71
# [[2 3 5]
#  [7 1 0]
#  [4 6 8]]
# Visitando #72
# [[2 3 0]
#  [7 1 5]
#  [4 6 8]]
# [[2 3 5]
#  [7 0 1]
#  [4 6 8]]
# Visitando #73
# [[2 0 5]
#  [7 3 1]
#  [4 6 8]]
# [[2 3 5]
#  [7 6 1]
#  [4 0 8]]
# [[2 3 5]
#  [0 7 1]
#  [4 6 8]]
# Visitando #74
# [[0 3 5]
#  [2 7 1]
#  [4 6 8]]
# [[2 3 5]
#  [4 7 1]
#  [0 6 8]]
# Visitando #75
# [[2 3 5]
#  [4 7 1]
#  [6 0 8]]
# Visitando #76
# [[2 3 5]
#  [4 0 1]
#  [6 7 8]]
# [[2 3 5]
#  [4 7 1]
#  [6 8 0]]
# Visitando #77
# [[2 3 5]
#  [4 7 0]
#  [6 8 1]]
# Visitando #78
# [[2 3 0]
#  [4 7 5]
#  [6 8 1]]
# [[2 3 5]
#  [4 0 7]
#  [6 8 1]]
# Visitando #79
# [[2 0 5]
#  [4 3 7]
#  [6 8 1]]
# [[2 3 5]
#  [4 8 7]
#  [6 0 1]]
# [[2 3 5]
#  [0 4 7]
#  [6 8 1]]
# Visitando #80
# [[0 3 5]
#  [2 4 7]
#  [6 8 1]]
# [[2 3 5]
#  [6 4 7]
#  [0 8 1]]
# Visitando #81
# [[2 3 5]
#  [6 4 7]
#  [8 0 1]]
# Visitando #82
# [[2 3 5]
#  [6 0 7]
#  [8 4 1]]
# [[2 3 5]
#  [6 4 7]
#  [8 1 0]]
# Visitando #83
# [[2 3 5]
#  [6 4 0]
#  [8 1 7]]
# Visitando #84
# [[2 3 0]
#  [6 4 5]
#  [8 1 7]]
# [[2 3 5]
#  [6 0 4]
#  [8 1 7]]
# Visitando #85
# [[2 0 5]
#  [6 3 4]
#  [8 1 7]]
# [[2 3 5]
#  [6 1 4]
#  [8 0 7]]
# [[2 3 5]
#  [0 6 4]
#  [8 1 7]]
# Visitando #86
# [[0 3 5]
#  [2 6 4]
#  [8 1 7]]
# [[2 3 5]
#  [8 6 4]
#  [0 1 7]]
# Visitando #87
# [[2 3 5]
#  [8 6 4]
#  [1 0 7]]
# Visitando #88
# [[2 3 5]
#  [8 0 4]
#  [1 6 7]]
# [[2 3 5]
#  [8 6 4]
#  [1 7 0]]
# Visitando #89
# [[2 3 5]
#  [8 6 0]
#  [1 7 4]]
# Visitando #90
# [[2 3 0]
#  [8 6 5]
#  [1 7 4]]
# [[2 3 5]
#  [8 0 6]
#  [1 7 4]]
# Visitando #91
# [[2 0 5]
#  [8 3 6]
#  [1 7 4]]
# [[2 3 5]
#  [8 7 6]
#  [1 0 4]]
# [[2 3 5]
#  [0 8 6]
#  [1 7 4]]
# Visitando #92
# [[0 3 5]
#  [2 8 6]
#  [1 7 4]]
# [[2 3 5]
#  [1 8 6]
#  [0 7 4]]
# Visitando #93
# [[2 3 5]
#  [1 8 6]
#  [7 0 4]]
# Visitando #94
# [[2 3 5]
#  [1 0 6]
#  [7 8 4]]
# [[2 3 5]
#  [1 8 6]
#  [7 4 0]]
# Visitando #95
# Visitando #96
# [[2 0 5]
#  [1 3 6]
#  [7 8 4]]
# [[2 3 5]
#  [0 1 6]
#  [7 8 4]]
# [[2 3 5]
#  [1 6 0]
#  [7 8 4]]
# Visitando #97
# [[2 3 0]
#  [1 6 5]
#  [7 8 4]]
# [[2 3 5]
#  [1 6 4]
#  [7 8 0]]
# Visitando #98
# [[2 3 5]
#  [1 6 4]
#  [7 0 8]]
# Visitando #99
# [[2 3 5]
#  [1 0 4]
#  [7 6 8]]
# [[2 3 5]
#  [1 6 4]
#  [0 7 8]]
# Visitando #100
# [[2 3 5]
#  [0 6 4]
#  [1 7 8]]
# Visitando #101
# [[0 3 5]
#  [2 6 4]
#  [1 7 8]]
# [[2 3 5]
#  [6 0 4]
#  [1 7 8]]
# Visitando #102
# [[2 0 5]
#  [6 3 4]
#  [1 7 8]]
# [[2 3 5]
#  [6 7 4]
#  [1 0 8]]
# [[2 3 5]
#  [6 4 0]
#  [1 7 8]]
# Visitando #103
# [[2 3 0]
#  [6 4 5]
#  [1 7 8]]
# [[2 3 5]
#  [6 4 8]
#  [1 7 0]]
# Visitando #104
# [[2 3 5]
#  [6 4 8]
#  [1 0 7]]
# Visitando #105
# [[2 3 5]
#  [6 0 8]
#  [1 4 7]]
# [[2 3 5]
#  [6 4 8]
#  [0 1 7]]
# Visitando #106
# [[2 3 5]
#  [0 4 8]
#  [6 1 7]]
# Visitando #107
# [[0 3 5]
#  [2 4 8]
#  [6 1 7]]
# [[2 3 5]
#  [4 0 8]
#  [6 1 7]]
# Visitando #108
# [[2 0 5]
#  [4 3 8]
#  [6 1 7]]
# [[2 3 5]
#  [4 1 8]
#  [6 0 7]]
# [[2 3 5]
#  [4 8 0]
#  [6 1 7]]
# Visitando #109
# [[2 3 0]
#  [4 8 5]
#  [6 1 7]]
# [[2 3 5]
#  [4 8 7]
#  [6 1 0]]
# Visitando #110
# [[2 3 5]
#  [4 8 7]
#  [6 0 1]]
# Visitando #111
# [[2 3 5]
#  [4 8 7]
#  [0 6 1]]
# Visitando #112
# [[2 3 5]
#  [0 8 7]
#  [4 6 1]]
# Visitando #113
# [[0 3 5]
#  [2 8 7]
#  [4 6 1]]
# [[2 3 5]
#  [8 0 7]
#  [4 6 1]]
# Visitando #114
# [[2 0 5]
#  [8 3 7]
#  [4 6 1]]
# [[2 3 5]
#  [8 6 7]
#  [4 0 1]]
# [[2 3 5]
#  [8 7 0]
#  [4 6 1]]
# Visitando #115
# [[2 3 0]
#  [8 7 5]
#  [4 6 1]]
# [[2 3 5]
#  [8 7 1]
#  [4 6 0]]
# Visitando #116
# [[2 3 5]
#  [8 7 1]
#  [4 0 6]]
# Visitando #117
# [[2 3 5]
#  [8 0 1]
#  [4 7 6]]
# [[2 3 5]
#  [8 7 1]
#  [0 4 6]]
# Visitando #118
# [[2 3 5]
#  [0 7 1]
#  [8 4 6]]
# Visitando #119
# [[0 3 5]
#  [2 7 1]
#  [8 4 6]]
# [[2 3 5]
#  [7 0 1]
#  [8 4 6]]
# Visitando #120
# [[2 0 5]
#  [7 3 1]
#  [8 4 6]]
# [[2 3 5]
#  [7 4 1]
#  [8 0 6]]
# [[2 3 5]
#  [7 1 0]
#  [8 4 6]]
# Visitando #121
# [[2 3 0]
#  [7 1 5]
#  [8 4 6]]
# [[2 3 5]
#  [7 1 6]
#  [8 4 0]]
# Visitando #122
# [[2 3 5]
#  [7 1 6]
#  [8 0 4]]
# Visitando #123
# [[2 3 5]
#  [7 0 6]
#  [8 1 4]]
# [[2 3 5]
#  [7 1 6]
#  [0 8 4]]
# Visitando #124
# [[2 3 5]
#  [0 1 6]
#  [7 8 4]]
# Visitando #125
# [[0 3 5]
#  [2 1 6]
#  [7 8 4]]
# Visitando #126
# [[3 0 5]
#  [2 1 6]
#  [7 8 4]]
# Visitando #127
# [[3 1 5]
#  [2 0 6]
#  [7 8 4]]
# [[3 5 0]
#  [2 1 6]
#  [7 8 4]]
# Visitando #128
# [[3 5 6]
#  [2 1 0]
#  [7 8 4]]
# Visitando #129
# [[3 5 6]
#  [2 1 4]
#  [7 8 0]]
# [[3 5 6]
#  [2 0 1]
#  [7 8 4]]
# Visitando #130
# [[3 0 6]
#  [2 5 1]
#  [7 8 4]]
# [[3 5 6]
#  [2 8 1]
#  [7 0 4]]
# [[3 5 6]
#  [0 2 1]
#  [7 8 4]]
# Visitando #131
# [[0 5 6]
#  [3 2 1]
#  [7 8 4]]
# [[3 5 6]
#  [7 2 1]
#  [0 8 4]]
# Visitando #132
# [[3 5 6]
#  [7 2 1]
#  [8 0 4]]
# Visitando #133
# [[3 5 6]
#  [7 0 1]
#  [8 2 4]]
# [[3 5 6]
#  [7 2 1]
#  [8 4 0]]
# Visitando #134
# [[3 5 6]
#  [7 2 0]
#  [8 4 1]]
# Visitando #135
# [[3 5 0]
#  [7 2 6]
#  [8 4 1]]
# [[3 5 6]
#  [7 0 2]
#  [8 4 1]]
# Visitando #136
# [[3 0 6]
#  [7 5 2]
#  [8 4 1]]
# [[3 5 6]
#  [7 4 2]
#  [8 0 1]]
# [[3 5 6]
#  [0 7 2]
#  [8 4 1]]
# Visitando #137
# [[0 5 6]
#  [3 7 2]
#  [8 4 1]]
# [[3 5 6]
#  [8 7 2]
#  [0 4 1]]
# Visitando #138
# [[3 5 6]
#  [8 7 2]
#  [4 0 1]]
# Visitando #139
# [[3 5 6]
#  [8 0 2]
#  [4 7 1]]
# [[3 5 6]
#  [8 7 2]
#  [4 1 0]]
# Visitando #140
# [[3 5 6]
#  [8 7 0]
#  [4 1 2]]
# Visitando #141
# [[3 5 0]
#  [8 7 6]
#  [4 1 2]]
# [[3 5 6]
#  [8 0 7]
#  [4 1 2]]
# Visitando #142
# [[3 0 6]
#  [8 5 7]
#  [4 1 2]]
# [[3 5 6]
#  [8 1 7]
#  [4 0 2]]
# [[3 5 6]
#  [0 8 7]
#  [4 1 2]]
# Visitando #143
# [[0 5 6]
#  [3 8 7]
#  [4 1 2]]
# [[3 5 6]
#  [4 8 7]
#  [0 1 2]]
# Visitando #144
# [[3 5 6]
#  [4 8 7]
#  [1 0 2]]
# Visitando #145
# [[3 5 6]
#  [4 0 7]
#  [1 8 2]]
# [[3 5 6]
#  [4 8 7]
#  [1 2 0]]
# Visitando #146
# [[3 5 6]
#  [4 8 0]
#  [1 2 7]]
# Visitando #147
# [[3 5 0]
#  [4 8 6]
#  [1 2 7]]
# [[3 5 6]
#  [4 0 8]
#  [1 2 7]]
# Visitando #148
# [[3 0 6]
#  [4 5 8]
#  [1 2 7]]
# [[3 5 6]
#  [4 2 8]
#  [1 0 7]]
# [[3 5 6]
#  [0 4 8]
#  [1 2 7]]
# Visitando #149
# [[0 5 6]
#  [3 4 8]
#  [1 2 7]]
# [[3 5 6]
#  [1 4 8]
#  [0 2 7]]
# Visitando #150
# [[3 5 6]
#  [1 4 8]
#  [2 0 7]]
# Visitando #151
# [[3 5 6]
#  [1 0 8]
#  [2 4 7]]
# [[3 5 6]
#  [1 4 8]
#  [2 7 0]]
# Visitando #152
# [[3 5 6]
#  [1 4 0]
#  [2 7 8]]
# Visitando #153
# [[3 5 0]
#  [1 4 6]
#  [2 7 8]]
# [[3 5 6]
#  [1 0 4]
#  [2 7 8]]
# Visitando #154
# [[3 0 6]
#  [1 5 4]
#  [2 7 8]]
# [[3 5 6]
#  [1 7 4]
#  [2 0 8]]
# [[3 5 6]
#  [0 1 4]
#  [2 7 8]]
# Visitando #155
# [[0 5 6]
#  [3 1 4]
#  [2 7 8]]
# [[3 5 6]
#  [2 1 4]
#  [0 7 8]]
# Visitando #156
# [[3 5 6]
#  [2 1 4]
#  [7 0 8]]
# Visitando #157
# [[3 5 6]
#  [2 0 4]
#  [7 1 8]]
# [[3 5 6]
#  [2 1 4]
#  [7 8 0]]
# Visitando #158
# Visitando #159
# [[3 0 6]
#  [2 5 4]
#  [7 1 8]]
# [[3 5 6]
#  [0 2 4]
#  [7 1 8]]
# [[3 5 6]
#  [2 4 0]
#  [7 1 8]]
# Visitando #160
# [[3 5 0]
#  [2 4 6]
#  [7 1 8]]
# [[3 5 6]
#  [2 4 8]
#  [7 1 0]]
# Visitando #161
# [[3 5 6]
#  [2 4 8]
#  [7 0 1]]
# Visitando #162
# [[3 5 6]
#  [2 0 8]
#  [7 4 1]]
# [[3 5 6]
#  [2 4 8]
#  [0 7 1]]
# Visitando #163
# [[3 5 6]
#  [0 4 8]
#  [2 7 1]]
# Visitando #164
# [[0 5 6]
#  [3 4 8]
#  [2 7 1]]
# [[3 5 6]
#  [4 0 8]
#  [2 7 1]]
# Visitando #165
# [[3 0 6]
#  [4 5 8]
#  [2 7 1]]
# [[3 5 6]
#  [4 7 8]
#  [2 0 1]]
# [[3 5 6]
#  [4 8 0]
#  [2 7 1]]
# Visitando #166
# [[3 5 0]
#  [4 8 6]
#  [2 7 1]]
# [[3 5 6]
#  [4 8 1]
#  [2 7 0]]
# Visitando #167
# [[3 5 6]
#  [4 8 1]
#  [2 0 7]]
# Visitando #168
# [[3 5 6]
#  [4 0 1]
#  [2 8 7]]
# [[3 5 6]
#  [4 8 1]
#  [0 2 7]]
# Visitando #169
# [[3 5 6]
#  [0 8 1]
#  [4 2 7]]
# Visitando #170
# [[0 5 6]
#  [3 8 1]
#  [4 2 7]]
# [[3 5 6]
#  [8 0 1]
#  [4 2 7]]
# Visitando #171
# [[3 0 6]
#  [8 5 1]
#  [4 2 7]]
# [[3 5 6]
#  [8 2 1]
#  [4 0 7]]
# [[3 5 6]
#  [8 1 0]
#  [4 2 7]]
# Visitando #172
# [[3 5 0]
#  [8 1 6]
#  [4 2 7]]
# [[3 5 6]
#  [8 1 7]
#  [4 2 0]]
# Visitando #173
# [[3 5 6]
#  [8 1 7]
#  [4 0 2]]
# Visitando #174
# [[3 5 6]
#  [8 1 7]
#  [0 4 2]]
# Visitando #175
# [[3 5 6]
#  [0 1 7]
#  [8 4 2]]
# Visitando #176
# [[0 5 6]
#  [3 1 7]
#  [8 4 2]]
# [[3 5 6]
#  [1 0 7]
#  [8 4 2]]
# Visitando #177
# [[3 0 6]
#  [1 5 7]
#  [8 4 2]]
# [[3 5 6]
#  [1 4 7]
#  [8 0 2]]
# [[3 5 6]
#  [1 7 0]
#  [8 4 2]]
# Visitando #178
# [[3 5 0]
#  [1 7 6]
#  [8 4 2]]
# [[3 5 6]
#  [1 7 2]
#  [8 4 0]]
# Visitando #179
# [[3 5 6]
#  [1 7 2]
#  [8 0 4]]
# Visitando #180
# [[3 5 6]
#  [1 0 2]
#  [8 7 4]]
# [[3 5 6]
#  [1 7 2]
#  [0 8 4]]
# Visitando #181
# [[3 5 6]
#  [0 7 2]
#  [1 8 4]]
# Visitando #182
# [[0 5 6]
#  [3 7 2]
#  [1 8 4]]
# [[3 5 6]
#  [7 0 2]
#  [1 8 4]]
# Visitando #183
# [[3 0 6]
#  [7 5 2]
#  [1 8 4]]
# [[3 5 6]
#  [7 8 2]
#  [1 0 4]]
# [[3 5 6]
#  [7 2 0]
#  [1 8 4]]
# Visitando #184
# [[3 5 0]
#  [7 2 6]
#  [1 8 4]]
# [[3 5 6]
#  [7 2 4]
#  [1 8 0]]
# Visitando #185
# [[3 5 6]
#  [7 2 4]
#  [1 0 8]]
# Visitando #186
# [[3 5 6]
#  [7 0 4]
#  [1 2 8]]
# [[3 5 6]
#  [7 2 4]
#  [0 1 8]]
# Visitando #187
# [[3 5 6]
#  [0 2 4]
#  [7 1 8]]
# Visitando #188
# [[0 5 6]
#  [3 2 4]
#  [7 1 8]]
# Visitando #189
# [[5 0 6]
#  [3 2 4]
#  [7 1 8]]
# Visitando #190
# [[5 2 6]
#  [3 0 4]
#  [7 1 8]]
# [[5 6 0]
#  [3 2 4]
#  [7 1 8]]
# Visitando #191
# [[5 6 4]
#  [3 2 0]
#  [7 1 8]]
# Visitando #192
# [[5 6 4]
#  [3 2 8]
#  [7 1 0]]
# [[5 6 4]
#  [3 0 2]
#  [7 1 8]]
# Visitando #193
# [[5 0 4]
#  [3 6 2]
#  [7 1 8]]
# [[5 6 4]
#  [3 1 2]
#  [7 0 8]]
# [[5 6 4]
#  [0 3 2]
#  [7 1 8]]
# Visitando #194
# [[0 6 4]
#  [5 3 2]
#  [7 1 8]]
# [[5 6 4]
#  [7 3 2]
#  [0 1 8]]
# Visitando #195
# [[5 6 4]
#  [7 3 2]
#  [1 0 8]]
# Visitando #196
# [[5 6 4]
#  [7 0 2]
#  [1 3 8]]
# [[5 6 4]
#  [7 3 2]
#  [1 8 0]]
# Visitando #197
# [[5 6 4]
#  [7 3 0]
#  [1 8 2]]
# Visitando #198
# [[5 6 0]
#  [7 3 4]
#  [1 8 2]]
# [[5 6 4]
#  [7 0 3]
#  [1 8 2]]
# Visitando #199
# [[5 0 4]
#  [7 6 3]
#  [1 8 2]]
# [[5 6 4]
#  [7 8 3]
#  [1 0 2]]
# [[5 6 4]
#  [0 7 3]
#  [1 8 2]]
# Visitando #200
# [[0 6 4]
#  [5 7 3]
#  [1 8 2]]
# [[5 6 4]
#  [1 7 3]
#  [0 8 2]]
# Visitando #201
# [[5 6 4]
#  [1 7 3]
#  [8 0 2]]
# Visitando #202
# [[5 6 4]
#  [1 0 3]
#  [8 7 2]]
# [[5 6 4]
#  [1 7 3]
#  [8 2 0]]
# Visitando #203
# [[5 6 4]
#  [1 7 0]
#  [8 2 3]]
# Visitando #204
# [[5 6 0]
#  [1 7 4]
#  [8 2 3]]
# [[5 6 4]
#  [1 0 7]
#  [8 2 3]]
# Visitando #205
# [[5 0 4]
#  [1 6 7]
#  [8 2 3]]
# [[5 6 4]
#  [1 2 7]
#  [8 0 3]]
# [[5 6 4]
#  [0 1 7]
#  [8 2 3]]
# Visitando #206
# [[0 6 4]
#  [5 1 7]
#  [8 2 3]]
# [[5 6 4]
#  [8 1 7]
#  [0 2 3]]
# Visitando #207
# [[5 6 4]
#  [8 1 7]
#  [2 0 3]]
# Visitando #208
# [[5 6 4]
#  [8 0 7]
#  [2 1 3]]
# [[5 6 4]
#  [8 1 7]
#  [2 3 0]]
# Visitando #209
# [[5 6 4]
#  [8 1 0]
#  [2 3 7]]
# Visitando #210
# [[5 6 0]
#  [8 1 4]
#  [2 3 7]]
# [[5 6 4]
#  [8 0 1]
#  [2 3 7]]
# Visitando #211
# [[5 0 4]
#  [8 6 1]
#  [2 3 7]]
# [[5 6 4]
#  [8 3 1]
#  [2 0 7]]
# [[5 6 4]
#  [0 8 1]
#  [2 3 7]]
# Visitando #212
# [[0 6 4]
#  [5 8 1]
#  [2 3 7]]
# [[5 6 4]
#  [2 8 1]
#  [0 3 7]]
# Visitando #213
# [[5 6 4]
#  [2 8 1]
#  [3 0 7]]
# Visitando #214
# [[5 6 4]
#  [2 0 1]
#  [3 8 7]]
# [[5 6 4]
#  [2 8 1]
#  [3 7 0]]
# Visitando #215
# [[5 6 4]
#  [2 8 0]
#  [3 7 1]]
# Visitando #216
# [[5 6 0]
#  [2 8 4]
#  [3 7 1]]
# [[5 6 4]
#  [2 0 8]
#  [3 7 1]]
# Visitando #217
# [[5 0 4]
#  [2 6 8]
#  [3 7 1]]
# [[5 6 4]
#  [2 7 8]
#  [3 0 1]]
# [[5 6 4]
#  [0 2 8]
#  [3 7 1]]
# Visitando #218
# [[0 6 4]
#  [5 2 8]
#  [3 7 1]]
# [[5 6 4]
#  [3 2 8]
#  [0 7 1]]
# Visitando #219
# [[5 6 4]
#  [3 2 8]
#  [7 0 1]]
# Visitando #220
# [[5 6 4]
#  [3 0 8]
#  [7 2 1]]
# [[5 6 4]
#  [3 2 8]
#  [7 1 0]]
# Visitando #221
# Visitando #222
# [[5 0 4]
#  [3 6 8]
#  [7 2 1]]
# [[5 6 4]
#  [0 3 8]
#  [7 2 1]]
# [[5 6 4]
#  [3 8 0]
#  [7 2 1]]
# Visitando #223
# [[5 6 0]
#  [3 8 4]
#  [7 2 1]]
# [[5 6 4]
#  [3 8 1]
#  [7 2 0]]
# Visitando #224
# [[5 6 4]
#  [3 8 1]
#  [7 0 2]]
# Visitando #225
# [[5 6 4]
#  [3 0 1]
#  [7 8 2]]
# [[5 6 4]
#  [3 8 1]
#  [0 7 2]]
# Visitando #226
# [[5 6 4]
#  [0 8 1]
#  [3 7 2]]
# Visitando #227
# [[0 6 4]
#  [5 8 1]
#  [3 7 2]]
# [[5 6 4]
#  [8 0 1]
#  [3 7 2]]
# Visitando #228
# [[5 0 4]
#  [8 6 1]
#  [3 7 2]]
# [[5 6 4]
#  [8 7 1]
#  [3 0 2]]
# [[5 6 4]
#  [8 1 0]
#  [3 7 2]]
# Visitando #229
# [[5 6 0]
#  [8 1 4]
#  [3 7 2]]
# [[5 6 4]
#  [8 1 2]
#  [3 7 0]]
# Visitando #230
# [[5 6 4]
#  [8 1 2]
#  [3 0 7]]
# Visitando #231
# [[5 6 4]
#  [8 0 2]
#  [3 1 7]]
# [[5 6 4]
#  [8 1 2]
#  [0 3 7]]
# Visitando #232
# [[5 6 4]
#  [0 1 2]
#  [8 3 7]]
# Visitando #233
# [[0 6 4]
#  [5 1 2]
#  [8 3 7]]
# [[5 6 4]
#  [1 0 2]
#  [8 3 7]]
# Visitando #234
# [[5 0 4]
#  [1 6 2]
#  [8 3 7]]
# [[5 6 4]
#  [1 3 2]
#  [8 0 7]]
# [[5 6 4]
#  [1 2 0]
#  [8 3 7]]
# Visitando #235
# [[5 6 0]
#  [1 2 4]
#  [8 3 7]]
# [[5 6 4]
#  [1 2 7]
#  [8 3 0]]
# Visitando #236
# [[5 6 4]
#  [1 2 7]
#  [8 0 3]]
# Visitando #237
# [[5 6 4]
#  [1 2 7]
#  [0 8 3]]
# Visitando #238
# [[5 6 4]
#  [0 2 7]
#  [1 8 3]]
# Visitando #239
# [[0 6 4]
#  [5 2 7]
#  [1 8 3]]
# [[5 6 4]
#  [2 0 7]
#  [1 8 3]]
# Visitando #240
# [[5 0 4]
#  [2 6 7]
#  [1 8 3]]
# [[5 6 4]
#  [2 8 7]
#  [1 0 3]]
# [[5 6 4]
#  [2 7 0]
#  [1 8 3]]
# Visitando #241
# [[5 6 0]
#  [2 7 4]
#  [1 8 3]]
# [[5 6 4]
#  [2 7 3]
#  [1 8 0]]
# Visitando #242
# [[5 6 4]
#  [2 7 3]
#  [1 0 8]]
# Visitando #243
# [[5 6 4]
#  [2 0 3]
#  [1 7 8]]
# [[5 6 4]
#  [2 7 3]
#  [0 1 8]]
# Visitando #244
# [[5 6 4]
#  [0 7 3]
#  [2 1 8]]
# Visitando #245
# [[0 6 4]
#  [5 7 3]
#  [2 1 8]]
# [[5 6 4]
#  [7 0 3]
#  [2 1 8]]
# Visitando #246
# [[5 0 4]
#  [7 6 3]
#  [2 1 8]]
# [[5 6 4]
#  [7 1 3]
#  [2 0 8]]
# [[5 6 4]
#  [7 3 0]
#  [2 1 8]]
# Visitando #247
# [[5 6 0]
#  [7 3 4]
#  [2 1 8]]
# [[5 6 4]
#  [7 3 8]
#  [2 1 0]]
# Visitando #248
# [[5 6 4]
#  [7 3 8]
#  [2 0 1]]
# Visitando #249
# [[5 6 4]
#  [7 0 8]
#  [2 3 1]]
# [[5 6 4]
#  [7 3 8]
#  [0 2 1]]
# Visitando #250
# [[5 6 4]
#  [0 3 8]
#  [7 2 1]]
# Visitando #251
# [[0 6 4]
#  [5 3 8]
#  [7 2 1]]
# Visitando #252
# [[6 0 4]
#  [5 3 8]
#  [7 2 1]]
# Visitando #253
# [[6 3 4]
#  [5 0 8]
#  [7 2 1]]
# [[6 4 0]
#  [5 3 8]
#  [7 2 1]]
# Visitando #254
# [[6 4 8]
#  [5 3 0]
#  [7 2 1]]
# Visitando #255
# [[6 4 8]
#  [5 3 1]
#  [7 2 0]]
# [[6 4 8]
#  [5 0 3]
#  [7 2 1]]
# Visitando #256
# [[6 0 8]
#  [5 4 3]
#  [7 2 1]]
# [[6 4 8]
#  [5 2 3]
#  [7 0 1]]
# [[6 4 8]
#  [0 5 3]
#  [7 2 1]]
# Visitando #257
# [[0 4 8]
#  [6 5 3]
#  [7 2 1]]
# [[6 4 8]
#  [7 5 3]
#  [0 2 1]]
# Visitando #258
# [[6 4 8]
#  [7 5 3]
#  [2 0 1]]
# Visitando #259
# [[6 4 8]
#  [7 0 3]
#  [2 5 1]]
# [[6 4 8]
#  [7 5 3]
#  [2 1 0]]
# Visitando #260
# [[6 4 8]
#  [7 5 0]
#  [2 1 3]]
# Visitando #261
# [[6 4 0]
#  [7 5 8]
#  [2 1 3]]
# [[6 4 8]
#  [7 0 5]
#  [2 1 3]]
# Visitando #262
# [[6 0 8]
#  [7 4 5]
#  [2 1 3]]
# [[6 4 8]
#  [7 1 5]
#  [2 0 3]]
# [[6 4 8]
#  [0 7 5]
#  [2 1 3]]
# Visitando #263
# [[0 4 8]
#  [6 7 5]
#  [2 1 3]]
# [[6 4 8]
#  [2 7 5]
#  [0 1 3]]
# Visitando #264
# [[6 4 8]
#  [2 7 5]
#  [1 0 3]]
# Visitando #265
# [[6 4 8]
#  [2 0 5]
#  [1 7 3]]
# [[6 4 8]
#  [2 7 5]
#  [1 3 0]]
# Visitando #266
# [[6 4 8]
#  [2 7 0]
#  [1 3 5]]
# Visitando #267
# [[6 4 0]
#  [2 7 8]
#  [1 3 5]]
# [[6 4 8]
#  [2 0 7]
#  [1 3 5]]
# Visitando #268
# [[6 0 8]
#  [2 4 7]
#  [1 3 5]]
# [[6 4 8]
#  [2 3 7]
#  [1 0 5]]
# [[6 4 8]
#  [0 2 7]
#  [1 3 5]]
# Visitando #269
# [[0 4 8]
#  [6 2 7]
#  [1 3 5]]
# [[6 4 8]
#  [1 2 7]
#  [0 3 5]]
# Visitando #270
# [[6 4 8]
#  [1 2 7]
#  [3 0 5]]
# Visitando #271
# [[6 4 8]
#  [1 0 7]
#  [3 2 5]]
# [[6 4 8]
#  [1 2 7]
#  [3 5 0]]
# Visitando #272
# [[6 4 8]
#  [1 2 0]
#  [3 5 7]]
# Visitando #273
# [[6 4 0]
#  [1 2 8]
#  [3 5 7]]
# [[6 4 8]
#  [1 0 2]
#  [3 5 7]]
# Visitando #274
# [[6 0 8]
#  [1 4 2]
#  [3 5 7]]
# [[6 4 8]
#  [1 5 2]
#  [3 0 7]]
# [[6 4 8]
#  [0 1 2]
#  [3 5 7]]
# Visitando #275
# [[0 4 8]
#  [6 1 2]
#  [3 5 7]]
# [[6 4 8]
#  [3 1 2]
#  [0 5 7]]
# Visitando #276
# [[6 4 8]
#  [3 1 2]
#  [5 0 7]]
# Visitando #277
# [[6 4 8]
#  [3 0 2]
#  [5 1 7]]
# [[6 4 8]
#  [3 1 2]
#  [5 7 0]]
# Visitando #278
# [[6 4 8]
#  [3 1 0]
#  [5 7 2]]
# Visitando #279
# [[6 4 0]
#  [3 1 8]
#  [5 7 2]]
# [[6 4 8]
#  [3 0 1]
#  [5 7 2]]
# Visitando #280
# [[6 0 8]
#  [3 4 1]
#  [5 7 2]]
# [[6 4 8]
#  [3 7 1]
#  [5 0 2]]
# [[6 4 8]
#  [0 3 1]
#  [5 7 2]]
# Visitando #281
# [[0 4 8]
#  [6 3 1]
#  [5 7 2]]
# [[6 4 8]
#  [5 3 1]
#  [0 7 2]]
# Visitando #282
# [[6 4 8]
#  [5 3 1]
#  [7 0 2]]
# Visitando #283
# [[6 4 8]
#  [5 0 1]
#  [7 3 2]]
# [[6 4 8]
#  [5 3 1]
#  [7 2 0]]
# Visitando #284
# Visitando #285
# [[6 0 8]
#  [5 4 1]
#  [7 3 2]]
# [[6 4 8]
#  [0 5 1]
#  [7 3 2]]
# [[6 4 8]
#  [5 1 0]
#  [7 3 2]]
# Visitando #286
# [[6 4 0]
#  [5 1 8]
#  [7 3 2]]
# [[6 4 8]
#  [5 1 2]
#  [7 3 0]]
# Visitando #287
# [[6 4 8]
#  [5 1 2]
#  [7 0 3]]
# Visitando #288
# [[6 4 8]
#  [5 0 2]
#  [7 1 3]]
# [[6 4 8]
#  [5 1 2]
#  [0 7 3]]
# Visitando #289
# [[6 4 8]
#  [0 1 2]
#  [5 7 3]]
# Visitando #290
# [[0 4 8]
#  [6 1 2]
#  [5 7 3]]
# [[6 4 8]
#  [1 0 2]
#  [5 7 3]]
# Visitando #291
# [[6 0 8]
#  [1 4 2]
#  [5 7 3]]
# [[6 4 8]
#  [1 7 2]
#  [5 0 3]]
# [[6 4 8]
#  [1 2 0]
#  [5 7 3]]
# Visitando #292
# [[6 4 0]
#  [1 2 8]
#  [5 7 3]]
# [[6 4 8]
#  [1 2 3]
#  [5 7 0]]
# Visitando #293
# [[6 4 8]
#  [1 2 3]
#  [5 0 7]]
# Visitando #294
# [[6 4 8]
#  [1 0 3]
#  [5 2 7]]
# [[6 4 8]
#  [1 2 3]
#  [0 5 7]]
# Visitando #295
# [[6 4 8]
#  [0 2 3]
#  [1 5 7]]
# Visitando #296
# [[0 4 8]
#  [6 2 3]
#  [1 5 7]]
# [[6 4 8]
#  [2 0 3]
#  [1 5 7]]
# Visitando #297
# [[6 0 8]
#  [2 4 3]
#  [1 5 7]]
# [[6 4 8]
#  [2 5 3]
#  [1 0 7]]
# [[6 4 8]
#  [2 3 0]
#  [1 5 7]]
# Visitando #298
# [[6 4 0]
#  [2 3 8]
#  [1 5 7]]
# [[6 4 8]
#  [2 3 7]
#  [1 5 0]]
# Visitando #299
# [[6 4 8]
#  [2 3 7]
#  [1 0 5]]
# Visitando #300
# [[6 4 8]
#  [2 3 7]
#  [0 1 5]]
# Visitando #301
# [[6 4 8]
#  [0 3 7]
#  [2 1 5]]
# Visitando #302
# [[0 4 8]
#  [6 3 7]
#  [2 1 5]]
# [[6 4 8]
#  [3 0 7]
#  [2 1 5]]
# Visitando #303
# [[6 0 8]
#  [3 4 7]
#  [2 1 5]]
# [[6 4 8]
#  [3 1 7]
#  [2 0 5]]
# [[6 4 8]
#  [3 7 0]
#  [2 1 5]]
# Visitando #304
# [[6 4 0]
#  [3 7 8]
#  [2 1 5]]
# [[6 4 8]
#  [3 7 5]
#  [2 1 0]]
# Visitando #305
# [[6 4 8]
#  [3 7 5]
#  [2 0 1]]
# Visitando #306
# [[6 4 8]
#  [3 0 5]
#  [2 7 1]]
# [[6 4 8]
#  [3 7 5]
#  [0 2 1]]
# Visitando #307
# [[6 4 8]
#  [0 7 5]
#  [3 2 1]]
# Visitando #308
# [[0 4 8]
#  [6 7 5]
#  [3 2 1]]
# [[6 4 8]
#  [7 0 5]
#  [3 2 1]]
# Visitando #309
# [[6 0 8]
#  [7 4 5]
#  [3 2 1]]
# [[6 4 8]
#  [7 2 5]
#  [3 0 1]]
# [[6 4 8]
#  [7 5 0]
#  [3 2 1]]
# Visitando #310
# [[6 4 0]
#  [7 5 8]
#  [3 2 1]]
# [[6 4 8]
#  [7 5 1]
#  [3 2 0]]
# Visitando #311
# [[6 4 8]
#  [7 5 1]
#  [3 0 2]]
# Visitando #312
# [[6 4 8]
#  [7 0 1]
#  [3 5 2]]
# [[6 4 8]
#  [7 5 1]
#  [0 3 2]]
# Visitando #313
# [[6 4 8]
#  [0 5 1]
#  [7 3 2]]
# Visitando #314
# [[0 4 8]
#  [6 5 1]
#  [7 3 2]]
# Visitando #315
# [[4 0 8]
#  [6 5 1]
#  [7 3 2]]
# Visitando #316
# [[4 5 8]
#  [6 0 1]
#  [7 3 2]]
# [[4 8 0]
#  [6 5 1]
#  [7 3 2]]
# Visitando #317
# [[4 8 1]
#  [6 5 0]
#  [7 3 2]]
# Visitando #318
# [[4 8 1]
#  [6 5 2]
#  [7 3 0]]
# [[4 8 1]
#  [6 0 5]
#  [7 3 2]]
# Visitando #319
# [[4 0 1]
#  [6 8 5]
#  [7 3 2]]
# [[4 8 1]
#  [6 3 5]
#  [7 0 2]]
# [[4 8 1]
#  [0 6 5]
#  [7 3 2]]
# Visitando #320
# [[0 8 1]
#  [4 6 5]
#  [7 3 2]]
# [[4 8 1]
#  [7 6 5]
#  [0 3 2]]
# Visitando #321
# [[4 8 1]
#  [7 6 5]
#  [3 0 2]]
# Visitando #322
# [[4 8 1]
#  [7 0 5]
#  [3 6 2]]
# [[4 8 1]
#  [7 6 5]
#  [3 2 0]]
# Visitando #323
# [[4 8 1]
#  [7 6 0]
#  [3 2 5]]
# Visitando #324
# [[4 8 0]
#  [7 6 1]
#  [3 2 5]]
# [[4 8 1]
#  [7 0 6]
#  [3 2 5]]
# Visitando #325
# [[4 0 1]
#  [7 8 6]
#  [3 2 5]]
# [[4 8 1]
#  [7 2 6]
#  [3 0 5]]
# [[4 8 1]
#  [0 7 6]
#  [3 2 5]]
# Visitando #326
# [[0 8 1]
#  [4 7 6]
#  [3 2 5]]
# [[4 8 1]
#  [3 7 6]
#  [0 2 5]]
# Visitando #327
# [[4 8 1]
#  [3 7 6]
#  [2 0 5]]
# Visitando #328
# [[4 8 1]
#  [3 0 6]
#  [2 7 5]]
# [[4 8 1]
#  [3 7 6]
#  [2 5 0]]
# Visitando #329
# [[4 8 1]
#  [3 7 0]
#  [2 5 6]]
# Visitando #330
# [[4 8 0]
#  [3 7 1]
#  [2 5 6]]
# [[4 8 1]
#  [3 0 7]
#  [2 5 6]]
# Visitando #331
# [[4 0 1]
#  [3 8 7]
#  [2 5 6]]
# [[4 8 1]
#  [3 5 7]
#  [2 0 6]]
# [[4 8 1]
#  [0 3 7]
#  [2 5 6]]
# Visitando #332
# [[0 8 1]
#  [4 3 7]
#  [2 5 6]]
# [[4 8 1]
#  [2 3 7]
#  [0 5 6]]
# Visitando #333
# [[4 8 1]
#  [2 3 7]
#  [5 0 6]]
# Visitando #334
# [[4 8 1]
#  [2 0 7]
#  [5 3 6]]
# [[4 8 1]
#  [2 3 7]
#  [5 6 0]]
# Visitando #335
# [[4 8 1]
#  [2 3 0]
#  [5 6 7]]
# Visitando #336
# [[4 8 0]
#  [2 3 1]
#  [5 6 7]]
# [[4 8 1]
#  [2 0 3]
#  [5 6 7]]
# Visitando #337
# [[4 0 1]
#  [2 8 3]
#  [5 6 7]]
# [[4 8 1]
#  [2 6 3]
#  [5 0 7]]
# [[4 8 1]
#  [0 2 3]
#  [5 6 7]]
# Visitando #338
# [[0 8 1]
#  [4 2 3]
#  [5 6 7]]
# [[4 8 1]
#  [5 2 3]
#  [0 6 7]]
# Visitando #339
# [[4 8 1]
#  [5 2 3]
#  [6 0 7]]
# Visitando #340
# [[4 8 1]
#  [5 0 3]
#  [6 2 7]]
# [[4 8 1]
#  [5 2 3]
#  [6 7 0]]
# Visitando #341
# [[4 8 1]
#  [5 2 0]
#  [6 7 3]]
# Visitando #342
# [[4 8 0]
#  [5 2 1]
#  [6 7 3]]
# [[4 8 1]
#  [5 0 2]
#  [6 7 3]]
# Visitando #343
# [[4 0 1]
#  [5 8 2]
#  [6 7 3]]
# [[4 8 1]
#  [5 7 2]
#  [6 0 3]]
# [[4 8 1]
#  [0 5 2]
#  [6 7 3]]
# Visitando #344
# [[0 8 1]
#  [4 5 2]
#  [6 7 3]]
# [[4 8 1]
#  [6 5 2]
#  [0 7 3]]
# Visitando #345
# [[4 8 1]
#  [6 5 2]
#  [7 0 3]]
# Visitando #346
# [[4 8 1]
#  [6 0 2]
#  [7 5 3]]
# [[4 8 1]
#  [6 5 2]
#  [7 3 0]]
# Visitando #347
# Visitando #348
# [[4 0 1]
#  [6 8 2]
#  [7 5 3]]
# [[4 8 1]
#  [0 6 2]
#  [7 5 3]]
# [[4 8 1]
#  [6 2 0]
#  [7 5 3]]
# Visitando #349
# [[4 8 0]
#  [6 2 1]
#  [7 5 3]]
# [[4 8 1]
#  [6 2 3]
#  [7 5 0]]
# Visitando #350
# [[4 8 1]
#  [6 2 3]
#  [7 0 5]]
# Visitando #351
# [[4 8 1]
#  [6 0 3]
#  [7 2 5]]
# [[4 8 1]
#  [6 2 3]
#  [0 7 5]]
# Visitando #352
# [[4 8 1]
#  [0 2 3]
#  [6 7 5]]
# Visitando #353
# [[0 8 1]
#  [4 2 3]
#  [6 7 5]]
# [[4 8 1]
#  [2 0 3]
#  [6 7 5]]
# Visitando #354
# [[4 0 1]
#  [2 8 3]
#  [6 7 5]]
# [[4 8 1]
#  [2 7 3]
#  [6 0 5]]
# [[4 8 1]
#  [2 3 0]
#  [6 7 5]]
# Visitando #355
# [[4 8 0]
#  [2 3 1]
#  [6 7 5]]
# [[4 8 1]
#  [2 3 5]
#  [6 7 0]]
# Visitando #356
# [[4 8 1]
#  [2 3 5]
#  [6 0 7]]
# Visitando #357
# [[4 8 1]
#  [2 0 5]
#  [6 3 7]]
# [[4 8 1]
#  [2 3 5]
#  [0 6 7]]
# Visitando #358
# [[4 8 1]
#  [0 3 5]
#  [2 6 7]]
# Visitando #359
# [[0 8 1]
#  [4 3 5]
#  [2 6 7]]
# [[4 8 1]
#  [3 0 5]
#  [2 6 7]]
# Visitando #360
# [[4 0 1]
#  [3 8 5]
#  [2 6 7]]
# [[4 8 1]
#  [3 6 5]
#  [2 0 7]]
# [[4 8 1]
#  [3 5 0]
#  [2 6 7]]
# Visitando #361
# [[4 8 0]
#  [3 5 1]
#  [2 6 7]]
# [[4 8 1]
#  [3 5 7]
#  [2 6 0]]
# Visitando #362
# [[4 8 1]
#  [3 5 7]
#  [2 0 6]]
# Visitando #363
# [[4 8 1]
#  [3 5 7]
#  [0 2 6]]
# Visitando #364
# [[4 8 1]
#  [0 5 7]
#  [3 2 6]]
# Visitando #365
# [[0 8 1]
#  [4 5 7]
#  [3 2 6]]
# [[4 8 1]
#  [5 0 7]
#  [3 2 6]]
# Visitando #366
# [[4 0 1]
#  [5 8 7]
#  [3 2 6]]
# [[4 8 1]
#  [5 2 7]
#  [3 0 6]]
# [[4 8 1]
#  [5 7 0]
#  [3 2 6]]
# Visitando #367
# [[4 8 0]
#  [5 7 1]
#  [3 2 6]]
# [[4 8 1]
#  [5 7 6]
#  [3 2 0]]
# Visitando #368
# [[4 8 1]
#  [5 7 6]
#  [3 0 2]]
# Visitando #369
# [[4 8 1]
#  [5 0 6]
#  [3 7 2]]
# [[4 8 1]
#  [5 7 6]
#  [0 3 2]]
# Visitando #370
# [[4 8 1]
#  [0 7 6]
#  [5 3 2]]
# Visitando #371
# [[0 8 1]
#  [4 7 6]
#  [5 3 2]]
# [[4 8 1]
#  [7 0 6]
#  [5 3 2]]
# Visitando #372
# [[4 0 1]
#  [7 8 6]
#  [5 3 2]]
# [[4 8 1]
#  [7 3 6]
#  [5 0 2]]
# [[4 8 1]
#  [7 6 0]
#  [5 3 2]]
# Visitando #373
# [[4 8 0]
#  [7 6 1]
#  [5 3 2]]
# [[4 8 1]
#  [7 6 2]
#  [5 3 0]]
# Visitando #374
# [[4 8 1]
#  [7 6 2]
#  [5 0 3]]
# Visitando #375
# [[4 8 1]
#  [7 0 2]
#  [5 6 3]]
# [[4 8 1]
#  [7 6 2]
#  [0 5 3]]
# Visitando #376
# [[4 8 1]
#  [0 6 2]
#  [7 5 3]]
# Visitando #377
# [[0 8 1]
#  [4 6 2]
#  [7 5 3]]
# Visitando #378
# [[8 0 1]
#  [4 6 2]
#  [7 5 3]]
# Visitando #379
# [[8 6 1]
#  [4 0 2]
#  [7 5 3]]
# [[8 1 0]
#  [4 6 2]
#  [7 5 3]]
# Visitando #380
# [[8 1 2]
#  [4 6 0]
#  [7 5 3]]
# Visitando #381
# [[8 1 2]
#  [4 6 3]
#  [7 5 0]]
# [[8 1 2]
#  [4 0 6]
#  [7 5 3]]
# Visitando #382
# [[8 0 2]
#  [4 1 6]
#  [7 5 3]]
# [[8 1 2]
#  [4 5 6]
#  [7 0 3]]
# [[8 1 2]
#  [0 4 6]
#  [7 5 3]]
# Visitando #383
# [[0 1 2]
#  [8 4 6]
#  [7 5 3]]
# [[8 1 2]
#  [7 4 6]
#  [0 5 3]]
# Visitando #384
# [[8 1 2]
#  [7 4 6]
#  [5 0 3]]
# Visitando #385
# [[8 1 2]
#  [7 0 6]
#  [5 4 3]]
# [[8 1 2]
#  [7 4 6]
#  [5 3 0]]
# Visitando #386
# [[8 1 2]
#  [7 4 0]
#  [5 3 6]]
# Visitando #387
# [[8 1 0]
#  [7 4 2]
#  [5 3 6]]
# [[8 1 2]
#  [7 0 4]
#  [5 3 6]]
# Visitando #388
# [[8 0 2]
#  [7 1 4]
#  [5 3 6]]
# [[8 1 2]
#  [7 3 4]
#  [5 0 6]]
# [[8 1 2]
#  [0 7 4]
#  [5 3 6]]
# Visitando #389
# [[0 1 2]
#  [8 7 4]
#  [5 3 6]]
# [[8 1 2]
#  [5 7 4]
#  [0 3 6]]
# Visitando #390
# [[8 1 2]
#  [5 7 4]
#  [3 0 6]]
# Visitando #391
# [[8 1 2]
#  [5 0 4]
#  [3 7 6]]
# [[8 1 2]
#  [5 7 4]
#  [3 6 0]]
# Visitando #392
# [[8 1 2]
#  [5 7 0]
#  [3 6 4]]
# Visitando #393
# [[8 1 0]
#  [5 7 2]
#  [3 6 4]]
# [[8 1 2]
#  [5 0 7]
#  [3 6 4]]
# Visitando #394
# [[8 0 2]
#  [5 1 7]
#  [3 6 4]]
# [[8 1 2]
#  [5 6 7]
#  [3 0 4]]
# [[8 1 2]
#  [0 5 7]
#  [3 6 4]]
# Visitando #395
# [[0 1 2]
#  [8 5 7]
#  [3 6 4]]
# [[8 1 2]
#  [3 5 7]
#  [0 6 4]]
# Visitando #396
# [[8 1 2]
#  [3 5 7]
#  [6 0 4]]
# Visitando #397
# [[8 1 2]
#  [3 0 7]
#  [6 5 4]]
# [[8 1 2]
#  [3 5 7]
#  [6 4 0]]
# Visitando #398
# [[8 1 2]
#  [3 5 0]
#  [6 4 7]]
# Visitando #399
# [[8 1 0]
#  [3 5 2]
#  [6 4 7]]
# [[8 1 2]
#  [3 0 5]
#  [6 4 7]]
# Visitando #400
# [[8 0 2]
#  [3 1 5]
#  [6 4 7]]
# [[8 1 2]
#  [3 4 5]
#  [6 0 7]]
# [[8 1 2]
#  [0 3 5]
#  [6 4 7]]
# Visitando #401
# [[0 1 2]
#  [8 3 5]
#  [6 4 7]]
# [[8 1 2]
#  [6 3 5]
#  [0 4 7]]
# Visitando #402
# [[8 1 2]
#  [6 3 5]
#  [4 0 7]]
# Visitando #403
# [[8 1 2]
#  [6 0 5]
#  [4 3 7]]
# [[8 1 2]
#  [6 3 5]
#  [4 7 0]]
# Visitando #404
# [[8 1 2]
#  [6 3 0]
#  [4 7 5]]
# Visitando #405
# [[8 1 0]
#  [6 3 2]
#  [4 7 5]]
# [[8 1 2]
#  [6 0 3]
#  [4 7 5]]
# Visitando #406
# [[8 0 2]
#  [6 1 3]
#  [4 7 5]]
# [[8 1 2]
#  [6 7 3]
#  [4 0 5]]
# [[8 1 2]
#  [0 6 3]
#  [4 7 5]]
# Visitando #407
# [[0 1 2]
#  [8 6 3]
#  [4 7 5]]
# [[8 1 2]
#  [4 6 3]
#  [0 7 5]]
# Visitando #408
# [[8 1 2]
#  [4 6 3]
#  [7 0 5]]
# Visitando #409
# [[8 1 2]
#  [4 0 3]
#  [7 6 5]]
# [[8 1 2]
#  [4 6 3]
#  [7 5 0]]
# Visitando #410
# Visitando #411
# [[8 0 2]
#  [4 1 3]
#  [7 6 5]]
# [[8 1 2]
#  [0 4 3]
#  [7 6 5]]
# [[8 1 2]
#  [4 3 0]
#  [7 6 5]]
# Visitando #412
# [[8 1 0]
#  [4 3 2]
#  [7 6 5]]
# [[8 1 2]
#  [4 3 5]
#  [7 6 0]]
# Visitando #413
# [[8 1 2]
#  [4 3 5]
#  [7 0 6]]
# Visitando #414
# [[8 1 2]
#  [4 0 5]
#  [7 3 6]]
# [[8 1 2]
#  [4 3 5]
#  [0 7 6]]
# Visitando #415
# [[8 1 2]
#  [0 3 5]
#  [4 7 6]]
# Visitando #416
# [[0 1 2]
#  [8 3 5]
#  [4 7 6]]
# [[8 1 2]
#  [3 0 5]
#  [4 7 6]]
# Visitando #417
# [[8 0 2]
#  [3 1 5]
#  [4 7 6]]
# [[8 1 2]
#  [3 7 5]
#  [4 0 6]]
# [[8 1 2]
#  [3 5 0]
#  [4 7 6]]
# Visitando #418
# [[8 1 0]
#  [3 5 2]
#  [4 7 6]]
# [[8 1 2]
#  [3 5 6]
#  [4 7 0]]
# Visitando #419
# [[8 1 2]
#  [3 5 6]
#  [4 0 7]]
# Visitando #420
# [[8 1 2]
#  [3 0 6]
#  [4 5 7]]
# [[8 1 2]
#  [3 5 6]
#  [0 4 7]]
# Visitando #421
# [[8 1 2]
#  [0 5 6]
#  [3 4 7]]
# Visitando #422
# [[0 1 2]
#  [8 5 6]
#  [3 4 7]]
# [[8 1 2]
#  [5 0 6]
#  [3 4 7]]
# Visitando #423
# [[8 0 2]
#  [5 1 6]
#  [3 4 7]]
# [[8 1 2]
#  [5 4 6]
#  [3 0 7]]
# [[8 1 2]
#  [5 6 0]
#  [3 4 7]]
# Visitando #424
# [[8 1 0]
#  [5 6 2]
#  [3 4 7]]
# [[8 1 2]
#  [5 6 7]
#  [3 4 0]]
# Visitando #425
# [[8 1 2]
#  [5 6 7]
#  [3 0 4]]
# Visitando #426
# [[8 1 2]
#  [5 6 7]
#  [0 3 4]]
# Visitando #427
# [[8 1 2]
#  [0 6 7]
#  [5 3 4]]
# Visitando #428
# [[0 1 2]
#  [8 6 7]
#  [5 3 4]]
# [[8 1 2]
#  [6 0 7]
#  [5 3 4]]
# Visitando #429
# [[8 0 2]
#  [6 1 7]
#  [5 3 4]]
# [[8 1 2]
#  [6 3 7]
#  [5 0 4]]
# [[8 1 2]
#  [6 7 0]
#  [5 3 4]]
# Visitando #430
# [[8 1 0]
#  [6 7 2]
#  [5 3 4]]
# [[8 1 2]
#  [6 7 4]
#  [5 3 0]]
# Visitando #431
# [[8 1 2]
#  [6 7 4]
#  [5 0 3]]
# Visitando #432
# [[8 1 2]
#  [6 0 4]
#  [5 7 3]]
# [[8 1 2]
#  [6 7 4]
#  [0 5 3]]
# Visitando #433
# [[8 1 2]
#  [0 7 4]
#  [6 5 3]]
# Visitando #434
# [[0 1 2]
#  [8 7 4]
#  [6 5 3]]
# [[8 1 2]
#  [7 0 4]
#  [6 5 3]]
# Visitando #435
# [[8 0 2]
#  [7 1 4]
#  [6 5 3]]
# [[8 1 2]
#  [7 5 4]
#  [6 0 3]]
# [[8 1 2]
#  [7 4 0]
#  [6 5 3]]
# Visitando #436
# [[8 1 0]
#  [7 4 2]
#  [6 5 3]]
# [[8 1 2]
#  [7 4 3]
#  [6 5 0]]
# Visitando #437
# [[8 1 2]
#  [7 4 3]
#  [6 0 5]]
# Visitando #438
# [[8 1 2]
#  [7 0 3]
#  [6 4 5]]
# [[8 1 2]
#  [7 4 3]
#  [0 6 5]]
# Visitando #439
# [[8 1 2]
#  [0 4 3]
#  [7 6 5]]
# Visitando #440
# [[0 1 2]
#  [8 4 3]
#  [7 6 5]]
# Visitando #441
# Visitando #442
# [[8 0 2]
#  [7 1 3]
#  [6 4 5]]
# [[8 1 2]
#  [0 7 3]
#  [6 4 5]]
# [[8 1 2]
#  [7 3 0]
#  [6 4 5]]
# Visitando #443
# [[8 1 0]
#  [7 3 2]
#  [6 4 5]]
# [[8 1 2]
#  [7 3 5]
#  [6 4 0]]
# Visitando #444
# [[8 1 2]
#  [7 3 5]
#  [6 0 4]]
# Visitando #445
# [[8 1 2]
#  [7 0 5]
#  [6 3 4]]
# [[8 1 2]
#  [7 3 5]
#  [0 6 4]]
# Visitando #446
# [[8 1 2]
#  [0 3 5]
#  [7 6 4]]
# Visitando #447
# [[0 1 2]
#  [8 3 5]
#  [7 6 4]]
# [[8 1 2]
#  [3 0 5]
#  [7 6 4]]
# Visitando #448
# [[8 0 2]
#  [3 1 5]
#  [7 6 4]]
# [[8 1 2]
#  [3 6 5]
#  [7 0 4]]
# [[8 1 2]
#  [3 5 0]
#  [7 6 4]]
# Visitando #449
# [[8 1 0]
#  [3 5 2]
#  [7 6 4]]
# [[8 1 2]
#  [3 5 4]
#  [7 6 0]]
# Visitando #450
# [[8 1 2]
#  [3 5 4]
#  [7 0 6]]
# Visitando #451
# [[8 1 2]
#  [3 0 4]
#  [7 5 6]]
# [[8 1 2]
#  [3 5 4]
#  [0 7 6]]
# Visitando #452
# [[8 1 2]
#  [0 5 4]
#  [3 7 6]]
# Visitando #453
# [[0 1 2]
#  [8 5 4]
#  [3 7 6]]
# [[8 1 2]
#  [5 0 4]
#  [3 7 6]]
# Visitando #454
# [[8 0 2]
#  [5 1 4]
#  [3 7 6]]
# [[8 1 2]
#  [5 4 0]
#  [3 7 6]]
# Visitando #455
# [[8 1 0]
#  [5 4 2]
#  [3 7 6]]
# [[8 1 2]
#  [5 4 6]
#  [3 7 0]]
# Visitando #456
# [[8 1 2]
#  [5 4 6]
#  [3 0 7]]
# Visitando #457
# [[8 1 2]
#  [5 4 6]
#  [0 3 7]]
# Visitando #458
# [[8 1 2]
#  [0 4 6]
#  [5 3 7]]
# Visitando #459
# [[0 1 2]
#  [8 4 6]
#  [5 3 7]]
# [[8 1 2]
#  [4 0 6]
#  [5 3 7]]
# Visitando #460
# [[8 0 2]
#  [4 1 6]
#  [5 3 7]]
# [[8 1 2]
#  [4 3 6]
#  [5 0 7]]
# [[8 1 2]
#  [4 6 0]
#  [5 3 7]]
# Visitando #461
# [[8 1 0]
#  [4 6 2]
#  [5 3 7]]
# [[8 1 2]
#  [4 6 7]
#  [5 3 0]]
# Visitando #462
# [[8 1 2]
#  [4 6 7]
#  [5 0 3]]
# Visitando #463
# [[8 1 2]
#  [4 0 7]
#  [5 6 3]]
# [[8 1 2]
#  [4 6 7]
#  [0 5 3]]
# Visitando #464
# [[8 1 2]
#  [0 6 7]
#  [4 5 3]]
# Visitando #465
# [[0 1 2]
#  [8 6 7]
#  [4 5 3]]
# [[8 1 2]
#  [6 0 7]
#  [4 5 3]]
# Visitando #466
# [[8 0 2]
#  [6 1 7]
#  [4 5 3]]
# [[8 1 2]
#  [6 5 7]
#  [4 0 3]]
# [[8 1 2]
#  [6 7 0]
#  [4 5 3]]
# Visitando #467
# [[8 1 0]
#  [6 7 2]
#  [4 5 3]]
# [[8 1 2]
#  [6 7 3]
#  [4 5 0]]
# Visitando #468
# [[8 1 2]
#  [6 7 3]
#  [4 0 5]]
# Visitando #469
# [[8 1 2]
#  [6 7 3]
#  [0 4 5]]
# Visitando #470
# [[8 1 2]
#  [0 7 3]
#  [6 4 5]]
# Visitando #471
# [[0 1 2]
#  [8 7 3]
#  [6 4 5]]
# Visitando #472
# [[1 0 2]
#  [8 7 3]
#  [6 4 5]]
# Visitando #473
# [[1 7 2]
#  [8 0 3]
#  [6 4 5]]
# [[1 2 0]
#  [8 7 3]
#  [6 4 5]]
# Visitando #474
# [[1 2 3]
#  [8 7 0]
#  [6 4 5]]
# Visitando #475
# [[1 2 3]
#  [8 7 5]
#  [6 4 0]]
# [[1 2 3]
#  [8 0 7]
#  [6 4 5]]
# Visitando #476
# [[1 0 3]
#  [8 2 7]
#  [6 4 5]]
# [[1 2 3]
#  [8 4 7]
#  [6 0 5]]
# [[1 2 3]
#  [0 8 7]
#  [6 4 5]]
# Visitando #477
# [[0 2 3]
#  [1 8 7]
#  [6 4 5]]
# [[1 2 3]
#  [6 8 7]
#  [0 4 5]]
# Visitando #478
# [[1 2 3]
#  [6 8 7]
#  [4 0 5]]
# Visitando #479
# [[1 2 3]
#  [6 0 7]
#  [4 8 5]]
# [[1 2 3]
#  [6 8 7]
#  [4 5 0]]
# Visitando #480
# [[1 2 3]
#  [6 8 0]
#  [4 5 7]]
# Visitando #481
# [[1 2 0]
#  [6 8 3]
#  [4 5 7]]
# [[1 2 3]
#  [6 0 8]
#  [4 5 7]]
# Visitando #482
# [[1 0 3]
#  [6 2 8]
#  [4 5 7]]
# [[1 2 3]
#  [6 5 8]
#  [4 0 7]]
# [[1 2 3]
#  [0 6 8]
#  [4 5 7]]
# Visitando #483
# [[0 2 3]
#  [1 6 8]
#  [4 5 7]]
# [[1 2 3]
#  [4 6 8]
#  [0 5 7]]
# Visitando #484
# [[1 2 3]
#  [4 6 8]
#  [5 0 7]]
# Visitando #485
# [[1 2 3]
#  [4 0 8]
#  [5 6 7]]
# [[1 2 3]
#  [4 6 8]
#  [5 7 0]]
# Visitando #486
# [[1 2 3]
#  [4 6 0]
#  [5 7 8]]
# Visitando #487
# [[1 2 0]
#  [4 6 3]
#  [5 7 8]]
# [[1 2 3]
#  [4 0 6]
#  [5 7 8]]
# Visitando #488
# [[1 0 3]
#  [4 2 6]
#  [5 7 8]]
# [[1 2 3]
#  [4 7 6]
#  [5 0 8]]
# [[1 2 3]
#  [0 4 6]
#  [5 7 8]]
# Visitando #489
# [[0 2 3]
#  [1 4 6]
#  [5 7 8]]
# [[1 2 3]
#  [5 4 6]
#  [0 7 8]]
# Visitando #490
# [[1 2 3]
#  [5 4 6]
#  [7 0 8]]
# Visitando #491
# [[1 2 3]
#  [5 0 6]
#  [7 4 8]]
# [[1 2 3]
#  [5 4 6]
#  [7 8 0]]
# Visitando #492
# [[1 2 3]
#  [5 4 0]
#  [7 8 6]]
# Visitando #493
# [[1 2 0]
#  [5 4 3]
#  [7 8 6]]
# [[1 2 3]
#  [5 0 4]
#  [7 8 6]]
# Visitando #494
# [[1 0 3]
#  [5 2 4]
#  [7 8 6]]
# [[1 2 3]
#  [5 8 4]
#  [7 0 6]]
# [[1 2 3]
#  [0 5 4]
#  [7 8 6]]
# Visitando #495
# [[0 2 3]
#  [1 5 4]
#  [7 8 6]]
# [[1 2 3]
#  [7 5 4]
#  [0 8 6]]
# Visitando #496
# [[1 2 3]
#  [7 5 4]
#  [8 0 6]]
# Visitando #497
# [[1 2 3]
#  [7 0 4]
#  [8 5 6]]
# [[1 2 3]
#  [7 5 4]
#  [8 6 0]]
# Visitando #498
# [[1 2 3]
#  [7 5 0]
#  [8 6 4]]
# Visitando #499
# [[1 2 0]
#  [7 5 3]
#  [8 6 4]]
# [[1 2 3]
#  [7 0 5]
#  [8 6 4]]
# Visitando #500
# [[1 0 3]
#  [7 2 5]
#  [8 6 4]]
# [[1 2 3]
#  [7 6 5]
#  [8 0 4]]
# [[1 2 3]
#  [0 7 5]
#  [8 6 4]]
# Visitando #501
# [[0 2 3]
#  [1 7 5]
#  [8 6 4]]
# [[1 2 3]
#  [8 7 5]
#  [0 6 4]]
# Visitando #502
# [[1 2 3]
#  [8 7 5]
#  [6 0 4]]
# Visitando #503
# [[1 2 3]
#  [8 0 5]
#  [6 7 4]]
# [[1 2 3]
#  [8 7 5]
#  [6 4 0]]
# Visitando #504
# Visitando #505
# [[1 0 3]
#  [8 2 5]
#  [6 7 4]]
# [[1 2 3]
#  [0 8 5]
#  [6 7 4]]
# [[1 2 3]
#  [8 5 0]
#  [6 7 4]]
# Visitando #506
# [[1 2 0]
#  [8 5 3]
#  [6 7 4]]
# [[1 2 3]
#  [8 5 4]
#  [6 7 0]]
# Visitando #507
# [[1 2 3]
#  [8 5 4]
#  [6 0 7]]
# Visitando #508
# [[1 2 3]
#  [8 0 4]
#  [6 5 7]]
# [[1 2 3]
#  [8 5 4]
#  [0 6 7]]
# Visitando #509
# [[1 2 3]
#  [0 5 4]
#  [8 6 7]]
# Visitando #510
# [[0 2 3]
#  [1 5 4]
#  [8 6 7]]
# [[1 2 3]
#  [5 0 4]
#  [8 6 7]]
# Visitando #511
# [[1 0 3]
#  [5 2 4]
#  [8 6 7]]
# [[1 2 3]
#  [5 4 0]
#  [8 6 7]]
# Visitando #512
# [[1 2 0]
#  [5 4 3]
#  [8 6 7]]
# [[1 2 3]
#  [5 4 7]
#  [8 6 0]]
# Visitando #513
# [[1 2 3]
#  [5 4 7]
#  [8 0 6]]
# Visitando #514
# [[1 2 3]
#  [5 0 7]
#  [8 4 6]]
# [[1 2 3]
#  [5 4 7]
#  [0 8 6]]
# Visitando #515
# [[1 2 3]
#  [0 4 7]
#  [5 8 6]]
# Visitando #516
# [[0 2 3]
#  [1 4 7]
#  [5 8 6]]
# [[1 2 3]
#  [4 0 7]
#  [5 8 6]]
# Visitando #517
# [[1 0 3]
#  [4 2 7]
#  [5 8 6]]
# [[1 2 3]
#  [4 8 7]
#  [5 0 6]]
# [[1 2 3]
#  [4 7 0]
#  [5 8 6]]
# Visitando #518
# [[1 2 0]
#  [4 7 3]
#  [5 8 6]]
# [[1 2 3]
#  [4 7 6]
#  [5 8 0]]
# Visitando #519
# [[1 2 3]
#  [4 7 6]
#  [5 0 8]]
# Visitando #520
# [[1 2 3]
#  [4 7 6]
#  [0 5 8]]
# Visitando #521
# [[1 2 3]
#  [0 7 6]
#  [4 5 8]]
# Visitando #522
# [[0 2 3]
#  [1 7 6]
#  [4 5 8]]
# [[1 2 3]
#  [7 0 6]
#  [4 5 8]]
# Visitando #523
# [[1 0 3]
#  [7 2 6]
#  [4 5 8]]
# [[1 2 3]
#  [7 5 6]
#  [4 0 8]]
# [[1 2 3]
#  [7 6 0]
#  [4 5 8]]
# Visitando #524
# [[1 2 0]
#  [7 6 3]
#  [4 5 8]]
# [[1 2 3]
#  [7 6 8]
#  [4 5 0]]
# Visitando #525
# [[1 2 3]
#  [7 6 8]
#  [4 0 5]]
# Visitando #526
# [[1 2 3]
#  [7 6 8]
#  [0 4 5]]
# Visitando #527
# [[1 2 3]
#  [0 6 8]
#  [7 4 5]]
# Visitando #528
# [[0 2 3]
#  [1 6 8]
#  [7 4 5]]
# [[1 2 3]
#  [6 0 8]
#  [7 4 5]]
# Visitando #529
# [[1 0 3]
#  [6 2 8]
#  [7 4 5]]
# [[1 2 3]
#  [6 4 8]
#  [7 0 5]]
# [[1 2 3]
#  [6 8 0]
#  [7 4 5]]
# Visitando #530
# [[1 2 0]
#  [6 8 3]
#  [7 4 5]]
# [[1 2 3]
#  [6 8 5]
#  [7 4 0]]
# Visitando #531
# [[1 2 3]
#  [6 8 5]
#  [7 0 4]]
# Visitando #532
# [[1 2 3]
#  [6 0 5]
#  [7 8 4]]
# [[1 2 3]
#  [6 8 5]
#  [0 7 4]]
# Visitando #533
# [[1 2 3]
#  [0 8 5]
#  [6 7 4]]
# Visitando #534
# [[0 2 3]
#  [1 8 5]
#  [6 7 4]]
# Visitando #535
# [[2 0 3]
#  [1 8 5]
#  [6 7 4]]
# Visitando #536
# [[2 8 3]
#  [1 0 5]
#  [6 7 4]]
# [[2 3 0]
#  [1 8 5]
#  [6 7 4]]
# Visitando #537
# [[2 3 5]
#  [1 8 0]
#  [6 7 4]]
# Visitando #538
# [[2 3 5]
#  [1 8 4]
#  [6 7 0]]
# [[2 3 5]
#  [1 0 8]
#  [6 7 4]]
# Visitando #539
# [[2 0 5]
#  [1 3 8]
#  [6 7 4]]
# [[2 3 5]
#  [1 7 8]
#  [6 0 4]]
# [[2 3 5]
#  [0 1 8]
#  [6 7 4]]
# Visitando #540
# [[0 3 5]
#  [2 1 8]
#  [6 7 4]]
# [[2 3 5]
#  [6 1 8]
#  [0 7 4]]
# Visitando #541
# [[2 3 5]
#  [6 1 8]
#  [7 0 4]]
# Visitando #542
# [[2 3 5]
#  [6 0 8]
#  [7 1 4]]
# [[2 3 5]
#  [6 1 8]
#  [7 4 0]]
# Visitando #543
# [[2 3 5]
#  [6 1 0]
#  [7 4 8]]
# Visitando #544
# [[2 3 0]
#  [6 1 5]
#  [7 4 8]]
# [[2 3 5]
#  [6 0 1]
#  [7 4 8]]
# Visitando #545
# [[2 0 5]
#  [6 3 1]
#  [7 4 8]]
# [[2 3 5]
#  [6 4 1]
#  [7 0 8]]
# [[2 3 5]
#  [0 6 1]
#  [7 4 8]]
# Visitando #546
# [[0 3 5]
#  [2 6 1]
#  [7 4 8]]
# [[2 3 5]
#  [7 6 1]
#  [0 4 8]]
# Visitando #547
# [[2 3 5]
#  [7 6 1]
#  [4 0 8]]
# Visitando #548
# [[2 3 5]
#  [7 6 1]
#  [4 8 0]]
# Visitando #549
# [[2 3 5]
#  [7 6 0]
#  [4 8 1]]
# Visitando #550
# [[2 3 0]
#  [7 6 5]
#  [4 8 1]]
# [[2 3 5]
#  [7 0 6]
#  [4 8 1]]
# Visitando #551
# [[2 0 5]
#  [7 3 6]
#  [4 8 1]]
# [[2 3 5]
#  [7 8 6]
#  [4 0 1]]
# [[2 3 5]
#  [0 7 6]
#  [4 8 1]]
# Visitando #552
# [[0 3 5]
#  [2 7 6]
#  [4 8 1]]
# [[2 3 5]
#  [4 7 6]
#  [0 8 1]]
# Visitando #553
# [[2 3 5]
#  [4 7 6]
#  [8 0 1]]
# Visitando #554
# [[2 3 5]
#  [4 0 6]
#  [8 7 1]]
# [[2 3 5]
#  [4 7 6]
#  [8 1 0]]
# Visitando #555
# [[2 3 5]
#  [4 7 0]
#  [8 1 6]]
# Visitando #556
# [[2 3 0]
#  [4 7 5]
#  [8 1 6]]
# [[2 3 5]
#  [4 0 7]
#  [8 1 6]]
# Visitando #557
# [[2 0 5]
#  [4 3 7]
#  [8 1 6]]
# [[2 3 5]
#  [4 1 7]
#  [8 0 6]]
# [[2 3 5]
#  [0 4 7]
#  [8 1 6]]
# Visitando #558
# [[0 3 5]
#  [2 4 7]
#  [8 1 6]]
# [[2 3 5]
#  [8 4 7]
#  [0 1 6]]
# Visitando #559
# [[2 3 5]
#  [8 4 7]
#  [1 0 6]]
# Visitando #560
# [[2 3 5]
#  [8 0 7]
#  [1 4 6]]
# [[2 3 5]
#  [8 4 7]
#  [1 6 0]]
# Visitando #561
# [[2 3 5]
#  [8 4 0]
#  [1 6 7]]
# Visitando #562
# [[2 3 0]
#  [8 4 5]
#  [1 6 7]]
# [[2 3 5]
#  [8 0 4]
#  [1 6 7]]
# Visitando #563
# [[2 0 5]
#  [8 3 4]
#  [1 6 7]]
# [[2 3 5]
#  [0 8 4]
#  [1 6 7]]
# Visitando #564
# [[0 3 5]
#  [2 8 4]
#  [1 6 7]]
# [[2 3 5]
#  [1 8 4]
#  [0 6 7]]
# Visitando #565
# [[2 3 5]
#  [1 8 4]
#  [6 0 7]]
# Visitando #566
# [[2 3 5]
#  [1 0 4]
#  [6 8 7]]
# [[2 3 5]
#  [1 8 4]
#  [6 7 0]]
# Visitando #567
# Visitando #568
# [[2 0 5]
#  [1 3 4]
#  [6 8 7]]
# [[2 3 5]
#  [0 1 4]
#  [6 8 7]]
# [[2 3 5]
#  [1 4 0]
#  [6 8 7]]
# Visitando #569
# [[2 3 0]
#  [1 4 5]
#  [6 8 7]]
# [[2 3 5]
#  [1 4 7]
#  [6 8 0]]
# Visitando #570
# [[2 3 5]
#  [1 4 7]
#  [6 0 8]]
# Visitando #571
# [[2 3 5]
#  [1 0 7]
#  [6 4 8]]
# [[2 3 5]
#  [1 4 7]
#  [0 6 8]]
# Visitando #572
# [[2 3 5]
#  [0 4 7]
#  [1 6 8]]
# Visitando #573
# [[0 3 5]
#  [2 4 7]
#  [1 6 8]]
# [[2 3 5]
#  [4 0 7]
#  [1 6 8]]
# Visitando #574
# [[2 0 5]
#  [4 3 7]
#  [1 6 8]]
# [[2 3 5]
#  [4 6 7]
#  [1 0 8]]
# [[2 3 5]
#  [4 7 0]
#  [1 6 8]]
# Visitando #575
# [[2 3 0]
#  [4 7 5]
#  [1 6 8]]
# [[2 3 5]
#  [4 7 8]
#  [1 6 0]]
# Visitando #576
# [[2 3 5]
#  [4 7 8]
#  [1 0 6]]
# Visitando #577
# [[2 3 5]
#  [4 0 8]
#  [1 7 6]]
# [[2 3 5]
#  [4 7 8]
#  [0 1 6]]
# Visitando #578
# [[2 3 5]
#  [0 7 8]
#  [4 1 6]]
# Visitando #579
# [[0 3 5]
#  [2 7 8]
#  [4 1 6]]
# [[2 3 5]
#  [7 0 8]
#  [4 1 6]]
# Visitando #580
# [[2 0 5]
#  [7 3 8]
#  [4 1 6]]
# [[2 3 5]
#  [7 8 0]
#  [4 1 6]]
# Visitando #581
# [[2 3 0]
#  [7 8 5]
#  [4 1 6]]
# [[2 3 5]
#  [7 8 6]
#  [4 1 0]]
# Visitando #582
# [[2 3 5]
#  [7 8 6]
#  [4 0 1]]
# Visitando #583
# [[2 3 5]
#  [7 8 6]
#  [0 4 1]]
# Visitando #584
# [[2 3 5]
#  [0 8 6]
#  [7 4 1]]
# Visitando #585
# [[0 3 5]
#  [2 8 6]
#  [7 4 1]]
# [[2 3 5]
#  [8 0 6]
#  [7 4 1]]
# Visitando #586
# [[2 0 5]
#  [8 3 6]
#  [7 4 1]]
# [[2 3 5]
#  [8 4 6]
#  [7 0 1]]
# [[2 3 5]
#  [8 6 0]
#  [7 4 1]]
# Visitando #587
# [[2 3 0]
#  [8 6 5]
#  [7 4 1]]
# [[2 3 5]
#  [8 6 1]
#  [7 4 0]]
# Visitando #588
# [[2 3 5]
#  [8 6 1]
#  [7 0 4]]
# Visitando #589
# [[2 3 5]
#  [8 0 1]
#  [7 6 4]]
# [[2 3 5]
#  [8 6 1]
#  [0 7 4]]
# Visitando #590
# [[2 3 5]
#  [0 6 1]
#  [8 7 4]]
# Visitando #591
# [[0 3 5]
#  [2 6 1]
#  [8 7 4]]
# [[2 3 5]
#  [6 0 1]
#  [8 7 4]]
# Visitando #592
# [[2 0 5]
#  [6 3 1]
#  [8 7 4]]
# [[2 3 5]
#  [6 7 1]
#  [8 0 4]]
# [[2 3 5]
#  [6 1 0]
#  [8 7 4]]
# Visitando #593
# [[2 3 0]
#  [6 1 5]
#  [8 7 4]]
# [[2 3 5]
#  [6 1 4]
#  [8 7 0]]
# Visitando #594
# [[2 3 5]
#  [6 1 4]
#  [8 0 7]]
# Visitando #595
# [[2 3 5]
#  [6 1 4]
#  [0 8 7]]
# Visitando #596
# [[2 3 5]
#  [0 1 4]
#  [6 8 7]]
# Visitando #597
# [[0 3 5]
#  [2 1 4]
#  [6 8 7]]
# Visitando #598
# [[3 0 5]
#  [2 1 4]
#  [6 8 7]]
# Visitando #599
# [[3 1 5]
#  [2 0 4]
#  [6 8 7]]
# [[3 5 0]
#  [2 1 4]
#  [6 8 7]]
# Visitando #600
# [[3 5 4]
#  [2 1 0]
#  [6 8 7]]
# Visitando #601
# [[3 5 4]
#  [2 1 7]
#  [6 8 0]]
# [[3 5 4]
#  [2 0 1]
#  [6 8 7]]
# Visitando #602
# [[3 0 4]
#  [2 5 1]
#  [6 8 7]]
# [[3 5 4]
#  [2 8 1]
#  [6 0 7]]
# [[3 5 4]
#  [0 2 1]
#  [6 8 7]]
# Visitando #603
# [[0 5 4]
#  [3 2 1]
#  [6 8 7]]
# [[3 5 4]
#  [6 2 1]
#  [0 8 7]]
# Visitando #604
# [[3 5 4]
#  [6 2 1]
#  [8 0 7]]
# Visitando #605
# [[3 5 4]
#  [6 0 1]
#  [8 2 7]]
# [[3 5 4]
#  [6 2 1]
#  [8 7 0]]
# Visitando #606
# [[3 5 4]
#  [6 2 0]
#  [8 7 1]]
# Visitando #607
# [[3 5 0]
#  [6 2 4]
#  [8 7 1]]
# [[3 5 4]
#  [6 0 2]
#  [8 7 1]]
# Visitando #608
# [[3 0 4]
#  [6 5 2]
#  [8 7 1]]
# [[3 5 4]
#  [6 7 2]
#  [8 0 1]]
# [[3 5 4]
#  [0 6 2]
#  [8 7 1]]
# Visitando #609
# [[0 5 4]
#  [3 6 2]
#  [8 7 1]]
# [[3 5 4]
#  [8 6 2]
#  [0 7 1]]
# Visitando #610
# [[3 5 4]
#  [8 6 2]
#  [7 0 1]]
# Visitando #611
# [[3 5 4]
#  [8 0 2]
#  [7 6 1]]
# [[3 5 4]
#  [8 6 2]
#  [7 1 0]]
# Visitando #612
# [[3 5 4]
#  [8 6 0]
#  [7 1 2]]
# Visitando #613
# [[3 5 0]
#  [8 6 4]
#  [7 1 2]]
# [[3 5 4]
#  [8 0 6]
#  [7 1 2]]
# Visitando #614
# [[3 0 4]
#  [8 5 6]
#  [7 1 2]]
# [[3 5 4]
#  [8 1 6]
#  [7 0 2]]
# [[3 5 4]
#  [0 8 6]
#  [7 1 2]]
# Visitando #615
# [[0 5 4]
#  [3 8 6]
#  [7 1 2]]
# [[3 5 4]
#  [7 8 6]
#  [0 1 2]]
# Visitando #616
# [[3 5 4]
#  [7 8 6]
#  [1 0 2]]
# Visitando #617
# [[3 5 4]
#  [7 0 6]
#  [1 8 2]]
# [[3 5 4]
#  [7 8 6]
#  [1 2 0]]
# Visitando #618
# [[3 5 4]
#  [7 8 0]
#  [1 2 6]]
# Visitando #619
# [[3 5 0]
#  [7 8 4]
#  [1 2 6]]
# [[3 5 4]
#  [7 0 8]
#  [1 2 6]]
# Visitando #620
# [[3 0 4]
#  [7 5 8]
#  [1 2 6]]
# [[3 5 4]
#  [7 2 8]
#  [1 0 6]]
# [[3 5 4]
#  [0 7 8]
#  [1 2 6]]
# Visitando #621
# [[0 5 4]
#  [3 7 8]
#  [1 2 6]]
# [[3 5 4]
#  [1 7 8]
#  [0 2 6]]
# Visitando #622
# [[3 5 4]
#  [1 7 8]
#  [2 0 6]]
# Visitando #623
# [[3 5 4]
#  [1 0 8]
#  [2 7 6]]
# [[3 5 4]
#  [1 7 8]
#  [2 6 0]]
# Visitando #624
# [[3 5 4]
#  [1 7 0]
#  [2 6 8]]
# Visitando #625
# [[3 5 0]
#  [1 7 4]
#  [2 6 8]]
# [[3 5 4]
#  [1 0 7]
#  [2 6 8]]
# Visitando #626
# [[3 0 4]
#  [1 5 7]
#  [2 6 8]]
# [[3 5 4]
#  [1 6 7]
#  [2 0 8]]
# [[3 5 4]
#  [0 1 7]
#  [2 6 8]]
# Visitando #627
# [[0 5 4]
#  [3 1 7]
#  [2 6 8]]
# [[3 5 4]
#  [2 1 7]
#  [0 6 8]]
# Visitando #628
# [[3 5 4]
#  [2 1 7]
#  [6 0 8]]
# Visitando #629
# [[3 5 4]
#  [2 0 7]
#  [6 1 8]]
# [[3 5 4]
#  [2 1 7]
#  [6 8 0]]
# Visitando #630
# Visitando #631
# [[3 0 4]
#  [2 5 7]
#  [6 1 8]]
# [[3 5 4]
#  [0 2 7]
#  [6 1 8]]
# [[3 5 4]
#  [2 7 0]
#  [6 1 8]]
# Visitando #632
# [[3 5 0]
#  [2 7 4]
#  [6 1 8]]
# [[3 5 4]
#  [2 7 8]
#  [6 1 0]]
# Visitando #633
# [[3 5 4]
#  [2 7 8]
#  [6 0 1]]
# Visitando #634
# [[3 5 4]
#  [2 0 8]
#  [6 7 1]]
# [[3 5 4]
#  [2 7 8]
#  [0 6 1]]
# Visitando #635
# [[3 5 4]
#  [0 7 8]
#  [2 6 1]]
# Visitando #636
# [[0 5 4]
#  [3 7 8]
#  [2 6 1]]
# [[3 5 4]
#  [7 0 8]
#  [2 6 1]]
# Visitando #637
# [[3 0 4]
#  [7 5 8]
#  [2 6 1]]
# [[3 5 4]
#  [7 6 8]
#  [2 0 1]]
# [[3 5 4]
#  [7 8 0]
#  [2 6 1]]
# Visitando #638
# [[3 5 0]
#  [7 8 4]
#  [2 6 1]]
# [[3 5 4]
#  [7 8 1]
#  [2 6 0]]
# Visitando #639
# [[3 5 4]
#  [7 8 1]
#  [2 0 6]]
# Visitando #640
# [[3 5 4]
#  [7 0 1]
#  [2 8 6]]
# [[3 5 4]
#  [7 8 1]
#  [0 2 6]]
# Visitando #641
# [[3 5 4]
#  [0 8 1]
#  [7 2 6]]
# Visitando #642
# [[0 5 4]
#  [3 8 1]
#  [7 2 6]]
# [[3 5 4]
#  [8 0 1]
#  [7 2 6]]
# Visitando #643
# [[3 0 4]
#  [8 5 1]
#  [7 2 6]]
# [[3 5 4]
#  [8 2 1]
#  [7 0 6]]
# [[3 5 4]
#  [8 1 0]
#  [7 2 6]]
# Visitando #644
# [[3 5 0]
#  [8 1 4]
#  [7 2 6]]
# [[3 5 4]
#  [8 1 6]
#  [7 2 0]]
# Visitando #645
# [[3 5 4]
#  [8 1 6]
#  [7 0 2]]
# Visitando #646
# [[3 5 4]
#  [8 1 6]
#  [0 7 2]]
# Visitando #647
# [[3 5 4]
#  [0 1 6]
#  [8 7 2]]
# Visitando #648
# [[0 5 4]
#  [3 1 6]
#  [8 7 2]]
# [[3 5 4]
#  [1 0 6]
#  [8 7 2]]
# Visitando #649
# [[3 0 4]
#  [1 5 6]
#  [8 7 2]]
# [[3 5 4]
#  [1 7 6]
#  [8 0 2]]
# [[3 5 4]
#  [1 6 0]
#  [8 7 2]]
# Visitando #650
# [[3 5 0]
#  [1 6 4]
#  [8 7 2]]
# [[3 5 4]
#  [1 6 2]
#  [8 7 0]]
# Visitando #651
# [[3 5 4]
#  [1 6 2]
#  [8 0 7]]
# Visitando #652
# [[3 5 4]
#  [1 0 2]
#  [8 6 7]]
# [[3 5 4]
#  [1 6 2]
#  [0 8 7]]
# Visitando #653
# [[3 5 4]
#  [0 6 2]
#  [1 8 7]]
# Visitando #654
# [[0 5 4]
#  [3 6 2]
#  [1 8 7]]
# [[3 5 4]
#  [6 0 2]
#  [1 8 7]]
# Visitando #655
# [[3 0 4]
#  [6 5 2]
#  [1 8 7]]
# [[3 5 4]
#  [6 8 2]
#  [1 0 7]]
# [[3 5 4]
#  [6 2 0]
#  [1 8 7]]
# Visitando #656
# [[3 5 0]
#  [6 2 4]
#  [1 8 7]]
# [[3 5 4]
#  [6 2 7]
#  [1 8 0]]
# Visitando #657
# [[3 5 4]
#  [6 2 7]
#  [1 0 8]]
# Visitando #658
# [[3 5 4]
#  [6 0 7]
#  [1 2 8]]
# [[3 5 4]
#  [6 2 7]
#  [0 1 8]]
# Visitando #659
# [[3 5 4]
#  [0 2 7]
#  [6 1 8]]
# Visitando #660
# [[0 5 4]
#  [3 2 7]
#  [6 1 8]]
# Visitando #661
# [[5 0 4]
#  [3 2 7]
#  [6 1 8]]
# Visitando #662
# [[5 2 4]
#  [3 0 7]
#  [6 1 8]]
# [[5 4 0]
#  [3 2 7]
#  [6 1 8]]
# Visitando #663
# [[5 4 7]
#  [3 2 0]
#  [6 1 8]]
# Visitando #664
# [[5 4 7]
#  [3 2 8]
#  [6 1 0]]
# [[5 4 7]
#  [3 0 2]
#  [6 1 8]]
# Visitando #665
# [[5 0 7]
#  [3 4 2]
#  [6 1 8]]
# [[5 4 7]
#  [3 1 2]
#  [6 0 8]]
# [[5 4 7]
#  [0 3 2]
#  [6 1 8]]
# Visitando #666
# [[0 4 7]
#  [5 3 2]
#  [6 1 8]]
# [[5 4 7]
#  [6 3 2]
#  [0 1 8]]
# Visitando #667
# [[5 4 7]
#  [6 3 2]
#  [1 0 8]]
# Visitando #668
# [[5 4 7]
#  [6 0 2]
#  [1 3 8]]
# [[5 4 7]
#  [6 3 2]
#  [1 8 0]]
# Visitando #669
# [[5 4 7]
#  [6 3 0]
#  [1 8 2]]
# Visitando #670
# [[5 4 0]
#  [6 3 7]
#  [1 8 2]]
# [[5 4 7]
#  [6 0 3]
#  [1 8 2]]
# Visitando #671
# [[5 0 7]
#  [6 4 3]
#  [1 8 2]]
# [[5 4 7]
#  [6 8 3]
#  [1 0 2]]
# [[5 4 7]
#  [0 6 3]
#  [1 8 2]]
# Visitando #672
# [[0 4 7]
#  [5 6 3]
#  [1 8 2]]
# [[5 4 7]
#  [1 6 3]
#  [0 8 2]]
# Visitando #673
# [[5 4 7]
#  [1 6 3]
#  [8 0 2]]
# Visitando #674
# [[5 4 7]
#  [1 0 3]
#  [8 6 2]]
# [[5 4 7]
#  [1 6 3]
#  [8 2 0]]
# Visitando #675
# [[5 4 7]
#  [1 6 0]
#  [8 2 3]]
# Visitando #676
# [[5 4 0]
#  [1 6 7]
#  [8 2 3]]
# [[5 4 7]
#  [1 0 6]
#  [8 2 3]]
# Visitando #677
# [[5 0 7]
#  [1 4 6]
#  [8 2 3]]
# [[5 4 7]
#  [1 2 6]
#  [8 0 3]]
# [[5 4 7]
#  [0 1 6]
#  [8 2 3]]
# Visitando #678
# [[0 4 7]
#  [5 1 6]
#  [8 2 3]]
# [[5 4 7]
#  [8 1 6]
#  [0 2 3]]
# Visitando #679
# [[5 4 7]
#  [8 1 6]
#  [2 0 3]]
# Visitando #680
# [[5 4 7]
#  [8 0 6]
#  [2 1 3]]
# [[5 4 7]
#  [8 1 6]
#  [2 3 0]]
# Visitando #681
# [[5 4 7]
#  [8 1 0]
#  [2 3 6]]
# Visitando #682
# [[5 4 0]
#  [8 1 7]
#  [2 3 6]]
# [[5 4 7]
#  [8 0 1]
# ...
# [[2 0 3]
#  [1 6 7]
#  [4 8 5]]
# [[2 6 3]
#  [1 8 7]
#  [4 0 5]]
# [[2 6 3]
#  [0 1 7]
#  [4 8 5]]
# Visitando #8949
# [[0 6 3]
#  [2 1 7]
#  [4 8 5]]
# [[2 6 3]
#  [4 1 7]
#  [0 8 5]]
# Visitando #8950
# [[2 6 3]
#  [4 1 7]
#  [8 0 5]]
# Visitando #8951
# [[2 6 3]
#  [4 0 7]
#  [8 1 5]]
# [[2 6 3]
#  [4 1 7]
#  [8 5 0]]
# Visitando #8952
# [[2 6 3]
#  [4 1 0]
#  [8 5 7]]
# Visitando #8953
# [[2 6 0]
#  [4 1 3]
#  [8 5 7]]
# [[2 6 3]
#  [4 0 1]
#  [8 5 7]]
# Visitando #8954
# [[2 0 3]
#  [4 6 1]
#  [8 5 7]]
# [[2 6 3]
#  [4 5 1]
#  [8 0 7]]
# [[2 6 3]
#  [0 4 1]
#  [8 5 7]]
# Visitando #8955
# [[0 6 3]
#  [2 4 1]
#  [8 5 7]]
# [[2 6 3]
#  [8 4 1]
#  [0 5 7]]
# Visitando #8956
# [[2 6 3]
#  [8 4 1]
#  [5 0 7]]
# Visitando #8957
# [[2 6 3]
#  [8 0 1]
#  [5 4 7]]
# [[2 6 3]
#  [8 4 1]
#  [5 7 0]]
# Visitando #8958
# [[2 6 3]
#  [8 4 0]
#  [5 7 1]]
# Visitando #8959
# [[2 6 0]
#  [8 4 3]
#  [5 7 1]]
# [[2 6 3]
#  [8 0 4]
#  [5 7 1]]
# Visitando #8960
# [[2 0 3]
#  [8 6 4]
#  [5 7 1]]
# [[2 6 3]
#  [8 7 4]
#  [5 0 1]]
# [[2 6 3]
#  [0 8 4]
#  [5 7 1]]
# Visitando #8961
# [[0 6 3]
#  [2 8 4]
#  [5 7 1]]
# [[2 6 3]
#  [5 8 4]
#  [0 7 1]]
# Visitando #8962
# [[2 6 3]
#  [5 8 4]
#  [7 0 1]]
# Visitando #8963
# [[2 6 3]
#  [5 0 4]
#  [7 8 1]]
# [[2 6 3]
#  [5 8 4]
#  [7 1 0]]
# Visitando #8964
# Visitando #8965
# [[2 0 3]
#  [5 6 4]
#  [7 8 1]]
# [[2 6 3]
#  [0 5 4]
#  [7 8 1]]
# [[2 6 3]
#  [5 4 0]
#  [7 8 1]]
# Visitando #8966
# [[2 6 0]
#  [5 4 3]
#  [7 8 1]]
# [[2 6 3]
#  [5 4 1]
#  [7 8 0]]
# Visitando #8967
# [[2 6 3]
#  [5 4 1]
#  [7 0 8]]
# Visitando #8968
# [[2 6 3]
#  [5 0 1]
#  [7 4 8]]
# [[2 6 3]
#  [5 4 1]
#  [0 7 8]]
# Visitando #8969
# [[2 6 3]
#  [0 4 1]
#  [5 7 8]]
# Visitando #8970
# [[0 6 3]
#  [2 4 1]
#  [5 7 8]]
# [[2 6 3]
#  [4 0 1]
#  [5 7 8]]
# Visitando #8971
# [[2 0 3]
#  [4 6 1]
#  [5 7 8]]
# [[2 6 3]
#  [4 7 1]
#  [5 0 8]]
# [[2 6 3]
#  [4 1 0]
#  [5 7 8]]
# Visitando #8972
# [[2 6 0]
#  [4 1 3]
#  [5 7 8]]
# [[2 6 3]
#  [4 1 8]
#  [5 7 0]]
# Visitando #8973
# [[2 6 3]
#  [4 1 8]
#  [5 0 7]]
# Visitando #8974
# [[2 6 3]
#  [4 0 8]
#  [5 1 7]]
# [[2 6 3]
#  [4 1 8]
#  [0 5 7]]
# Visitando #8975
# [[2 6 3]
#  [0 1 8]
#  [4 5 7]]
# Visitando #8976
# [[0 6 3]
#  [2 1 8]
#  [4 5 7]]
# [[2 6 3]
#  [1 0 8]
#  [4 5 7]]
# Visitando #8977
# [[2 0 3]
#  [1 6 8]
#  [4 5 7]]
# [[2 6 3]
#  [1 5 8]
#  [4 0 7]]
# [[2 6 3]
#  [1 8 0]
#  [4 5 7]]
# Visitando #8978
# [[2 6 0]
#  [1 8 3]
#  [4 5 7]]
# [[2 6 3]
#  [1 8 7]
#  [4 5 0]]
# Visitando #8979
# [[2 6 3]
#  [1 8 7]
#  [4 0 5]]
# Visitando #8980
# [[2 6 3]
#  [1 8 7]
#  [0 4 5]]
# Visitando #8981
# [[2 6 3]
#  [0 8 7]
#  [1 4 5]]
# Visitando #8982
# [[0 6 3]
#  [2 8 7]
#  [1 4 5]]
# [[2 6 3]
#  [8 0 7]
#  [1 4 5]]
# Visitando #8983
# [[2 0 3]
#  [8 6 7]
#  [1 4 5]]
# [[2 6 3]
#  [8 4 7]
#  [1 0 5]]
# [[2 6 3]
#  [8 7 0]
#  [1 4 5]]
# Visitando #8984
# [[2 6 0]
#  [8 7 3]
#  [1 4 5]]
# [[2 6 3]
#  [8 7 5]
#  [1 4 0]]
# Visitando #8985
# [[2 6 3]
#  [8 7 5]
#  [1 0 4]]
# Visitando #8986
# [[2 6 3]
#  [8 0 5]
#  [1 7 4]]
# [[2 6 3]
#  [8 7 5]
#  [0 1 4]]
# Visitando #8987
# [[2 6 3]
#  [0 7 5]
#  [8 1 4]]
# Visitando #8988
# [[0 6 3]
#  [2 7 5]
#  [8 1 4]]
# [[2 6 3]
#  [7 0 5]
#  [8 1 4]]
# Visitando #8989
# [[2 0 3]
#  [7 6 5]
#  [8 1 4]]
# [[2 6 3]
#  [7 1 5]
#  [8 0 4]]
# [[2 6 3]
#  [7 5 0]
#  [8 1 4]]
# Visitando #8990
# [[2 6 0]
#  [7 5 3]
#  [8 1 4]]
# [[2 6 3]
#  [7 5 4]
#  [8 1 0]]
# Visitando #8991
# [[2 6 3]
#  [7 5 4]
#  [8 0 1]]
# Visitando #8992
# [[2 6 3]
#  [7 0 4]
#  [8 5 1]]
# [[2 6 3]
#  [7 5 4]
#  [0 8 1]]
# Visitando #8993
# [[2 6 3]
#  [0 5 4]
#  [7 8 1]]
# Visitando #8994
# [[0 6 3]
#  [2 5 4]
#  [7 8 1]]
# Visitando #8995
# [[6 0 3]
#  [2 5 4]
#  [7 8 1]]
# Visitando #8996
# [[6 5 3]
#  [2 0 4]
#  [7 8 1]]
# [[6 3 0]
#  [2 5 4]
#  [7 8 1]]
# Visitando #8997
# [[6 3 4]
#  [2 5 0]
#  [7 8 1]]
# Visitando #8998
# [[6 3 4]
#  [2 5 1]
#  [7 8 0]]
# [[6 3 4]
#  [2 0 5]
#  [7 8 1]]
# Visitando #8999
# [[6 0 4]
#  [2 3 5]
#  [7 8 1]]
# [[6 3 4]
#  [2 8 5]
#  [7 0 1]]
# [[6 3 4]
#  [0 2 5]
#  [7 8 1]]
# Visitando #9000
# [[0 3 4]
#  [6 2 5]
#  [7 8 1]]
# [[6 3 4]
#  [7 2 5]
#  [0 8 1]]
# Visitando #9001
# [[6 3 4]
#  [7 2 5]
#  [8 0 1]]
# Visitando #9002
# [[6 3 4]
#  [7 0 5]
#  [8 2 1]]
# [[6 3 4]
#  [7 2 5]
#  [8 1 0]]
# Visitando #9003
# [[6 3 4]
#  [7 2 0]
#  [8 1 5]]
# Visitando #9004
# [[6 3 0]
#  [7 2 4]
#  [8 1 5]]
# [[6 3 4]
#  [7 0 2]
#  [8 1 5]]
# Visitando #9005
# [[6 0 4]
#  [7 3 2]
#  [8 1 5]]
# [[6 3 4]
#  [7 1 2]
#  [8 0 5]]
# [[6 3 4]
#  [0 7 2]
#  [8 1 5]]
# Visitando #9006
# [[0 3 4]
#  [6 7 2]
#  [8 1 5]]
# [[6 3 4]
#  [8 7 2]
#  [0 1 5]]
# Visitando #9007
# [[6 3 4]
#  [8 7 2]
#  [1 0 5]]
# Visitando #9008
# [[6 3 4]
#  [8 0 2]
#  [1 7 5]]
# [[6 3 4]
#  [8 7 2]
#  [1 5 0]]
# Visitando #9009
# [[6 3 4]
#  [8 7 0]
#  [1 5 2]]
# Visitando #9010
# [[6 3 0]
#  [8 7 4]
#  [1 5 2]]
# [[6 3 4]
#  [8 0 7]
#  [1 5 2]]
# Visitando #9011
# [[6 0 4]
#  [8 3 7]
#  [1 5 2]]
# [[6 3 4]
#  [8 5 7]
#  [1 0 2]]
# [[6 3 4]
#  [0 8 7]
#  [1 5 2]]
# Visitando #9012
# [[0 3 4]
#  [6 8 7]
#  [1 5 2]]
# [[6 3 4]
#  [1 8 7]
#  [0 5 2]]
# Visitando #9013
# [[6 3 4]
#  [1 8 7]
#  [5 0 2]]
# Visitando #9014
# [[6 3 4]
#  [1 0 7]
#  [5 8 2]]
# [[6 3 4]
#  [1 8 7]
#  [5 2 0]]
# Visitando #9015
# [[6 3 4]
#  [1 8 0]
#  [5 2 7]]
# Visitando #9016
# [[6 3 0]
#  [1 8 4]
#  [5 2 7]]
# [[6 3 4]
#  [1 0 8]
#  [5 2 7]]
# Visitando #9017
# [[6 0 4]
#  [1 3 8]
#  [5 2 7]]
# [[6 3 4]
#  [1 2 8]
#  [5 0 7]]
# [[6 3 4]
#  [0 1 8]
#  [5 2 7]]
# Visitando #9018
# [[0 3 4]
#  [6 1 8]
#  [5 2 7]]
# [[6 3 4]
#  [5 1 8]
#  [0 2 7]]
# Visitando #9019
# [[6 3 4]
#  [5 1 8]
#  [2 0 7]]
# Visitando #9020
# [[6 3 4]
#  [5 0 8]
#  [2 1 7]]
# [[6 3 4]
#  [5 1 8]
#  [2 7 0]]
# Visitando #9021
# [[6 3 4]
#  [5 1 0]
#  [2 7 8]]
# Visitando #9022
# [[6 3 0]
#  [5 1 4]
#  [2 7 8]]
# [[6 3 4]
#  [5 0 1]
#  [2 7 8]]
# Visitando #9023
# [[6 0 4]
#  [5 3 1]
#  [2 7 8]]
# [[6 3 4]
#  [5 7 1]
#  [2 0 8]]
# [[6 3 4]
#  [0 5 1]
#  [2 7 8]]
# Visitando #9024
# [[0 3 4]
#  [6 5 1]
#  [2 7 8]]
# [[6 3 4]
#  [2 5 1]
#  [0 7 8]]
# Visitando #9025
# [[6 3 4]
#  [2 5 1]
#  [7 0 8]]
# Visitando #9026
# [[6 3 4]
#  [2 0 1]
#  [7 5 8]]
# [[6 3 4]
#  [2 5 1]
#  [7 8 0]]
# Visitando #9027
# Visitando #9028
# [[6 0 4]
#  [2 3 1]
#  [7 5 8]]
# [[6 3 4]
#  [0 2 1]
#  [7 5 8]]
# [[6 3 4]
#  [2 1 0]
#  [7 5 8]]
# Visitando #9029
# [[6 3 0]
#  [2 1 4]
#  [7 5 8]]
# [[6 3 4]
#  [2 1 8]
#  [7 5 0]]
# Visitando #9030
# [[6 3 4]
#  [2 1 8]
#  [7 0 5]]
# Visitando #9031
# [[6 3 4]
#  [2 0 8]
#  [7 1 5]]
# [[6 3 4]
#  [2 1 8]
#  [0 7 5]]
# Visitando #9032
# [[6 3 4]
#  [0 1 8]
#  [2 7 5]]
# Visitando #9033
# [[0 3 4]
#  [6 1 8]
#  [2 7 5]]
# [[6 3 4]
#  [1 0 8]
#  [2 7 5]]
# Visitando #9034
# [[6 0 4]
#  [1 3 8]
#  [2 7 5]]
# [[6 3 4]
#  [1 7 8]
#  [2 0 5]]
# [[6 3 4]
#  [1 8 0]
#  [2 7 5]]
# Visitando #9035
# [[6 3 0]
#  [1 8 4]
#  [2 7 5]]
# [[6 3 4]
#  [1 8 5]
#  [2 7 0]]
# Visitando #9036
# [[6 3 4]
#  [1 8 5]
#  [2 0 7]]
# Visitando #9037
# [[6 3 4]
#  [1 0 5]
#  [2 8 7]]
# [[6 3 4]
#  [1 8 5]
#  [0 2 7]]
# Visitando #9038
# [[6 3 4]
#  [0 8 5]
#  [1 2 7]]
# Visitando #9039
# [[0 3 4]
#  [6 8 5]
#  [1 2 7]]
# [[6 3 4]
#  [8 0 5]
#  [1 2 7]]
# Visitando #9040
# [[6 0 4]
#  [8 3 5]
#  [1 2 7]]
# [[6 3 4]
#  [8 2 5]
#  [1 0 7]]
# [[6 3 4]
#  [8 5 0]
#  [1 2 7]]
# Visitando #9041
# [[6 3 0]
#  [8 5 4]
#  [1 2 7]]
# [[6 3 4]
#  [8 5 7]
#  [1 2 0]]
# Visitando #9042
# [[6 3 4]
#  [8 5 7]
#  [1 0 2]]
# Visitando #9043
# [[6 3 4]
#  [8 5 7]
#  [0 1 2]]
# Visitando #9044
# [[6 3 4]
#  [0 5 7]
#  [8 1 2]]
# Visitando #9045
# [[0 3 4]
#  [6 5 7]
#  [8 1 2]]
# [[6 3 4]
#  [5 0 7]
#  [8 1 2]]
# Visitando #9046
# [[6 0 4]
#  [5 3 7]
#  [8 1 2]]
# [[6 3 4]
#  [5 1 7]
#  [8 0 2]]
# [[6 3 4]
#  [5 7 0]
#  [8 1 2]]
# Visitando #9047
# [[6 3 0]
#  [5 7 4]
#  [8 1 2]]
# [[6 3 4]
#  [5 7 2]
#  [8 1 0]]
# Visitando #9048
# [[6 3 4]
#  [5 7 2]
#  [8 0 1]]
# Visitando #9049
# [[6 3 4]
#  [5 0 2]
#  [8 7 1]]
# [[6 3 4]
#  [5 7 2]
#  [0 8 1]]
# Visitando #9050
# [[6 3 4]
#  [0 7 2]
#  [5 8 1]]
# Visitando #9051
# [[0 3 4]
#  [6 7 2]
#  [5 8 1]]
# [[6 3 4]
#  [7 0 2]
#  [5 8 1]]
# Visitando #9052
# [[6 0 4]
#  [7 3 2]
#  [5 8 1]]
# [[6 3 4]
#  [7 8 2]
#  [5 0 1]]
# [[6 3 4]
#  [7 2 0]
#  [5 8 1]]
# Visitando #9053
# [[6 3 0]
#  [7 2 4]
#  [5 8 1]]
# [[6 3 4]
#  [7 2 1]
#  [5 8 0]]
# Visitando #9054
# [[6 3 4]
#  [7 2 1]
#  [5 0 8]]
# Visitando #9055
# [[6 3 4]
#  [7 0 1]
#  [5 2 8]]
# [[6 3 4]
#  [7 2 1]
#  [0 5 8]]
# Visitando #9056
# [[6 3 4]
#  [0 2 1]
#  [7 5 8]]
# Visitando #9057
# [[0 3 4]
#  [6 2 1]
#  [7 5 8]]
# Visitando #9058
# [[3 0 4]
#  [6 2 1]
#  [7 5 8]]
# Visitando #9059
# [[3 2 4]
#  [6 0 1]
#  [7 5 8]]
# [[3 4 0]
#  [6 2 1]
#  [7 5 8]]
# Visitando #9060
# Visitando #9061
# [[3 2 4]
#  [6 5 1]
#  [7 0 8]]
# [[3 2 4]
#  [0 6 1]
#  [7 5 8]]
# [[3 2 4]
#  [6 1 0]
#  [7 5 8]]
# Visitando #9062
# [[3 2 0]
#  [6 1 4]
#  [7 5 8]]
# [[3 2 4]
#  [6 1 8]
#  [7 5 0]]
# Visitando #9063
# [[3 2 4]
#  [6 1 8]
#  [7 0 5]]
# Visitando #9064
# [[3 2 4]
#  [6 0 8]
#  [7 1 5]]
# [[3 2 4]
#  [6 1 8]
#  [0 7 5]]
# Visitando #9065
# [[3 2 4]
#  [0 1 8]
#  [6 7 5]]
# Visitando #9066
# [[0 2 4]
#  [3 1 8]
#  [6 7 5]]
# [[3 2 4]
#  [1 0 8]
#  [6 7 5]]
# Visitando #9067
# [[3 0 4]
#  [1 2 8]
#  [6 7 5]]
# [[3 2 4]
#  [1 7 8]
#  [6 0 5]]
# [[3 2 4]
#  [1 8 0]
#  [6 7 5]]
# Visitando #9068
# [[3 2 0]
#  [1 8 4]
#  [6 7 5]]
# [[3 2 4]
#  [1 8 5]
#  [6 7 0]]
# Visitando #9069
# [[3 2 4]
#  [1 8 5]
#  [6 0 7]]
# Visitando #9070
# [[3 2 4]
#  [1 0 5]
#  [6 8 7]]
# [[3 2 4]
#  [1 8 5]
#  [0 6 7]]
# Visitando #9071
# [[3 2 4]
#  [0 8 5]
#  [1 6 7]]
# Visitando #9072
# [[0 2 4]
#  [3 8 5]
#  [1 6 7]]
# [[3 2 4]
#  [8 0 5]
#  [1 6 7]]
# Visitando #9073
# [[3 0 4]
#  [8 2 5]
#  [1 6 7]]
# [[3 2 4]
#  [8 6 5]
#  [1 0 7]]
# [[3 2 4]
#  [8 5 0]
#  [1 6 7]]
# Visitando #9074
# [[3 2 0]
#  [8 5 4]
#  [1 6 7]]
# [[3 2 4]
#  [8 5 7]
#  [1 6 0]]
# Visitando #9075
# [[3 2 4]
#  [8 5 7]
#  [1 0 6]]
# Visitando #9076
# [[3 2 4]
#  [8 0 7]
#  [1 5 6]]
# [[3 2 4]
#  [8 5 7]
#  [0 1 6]]
# Visitando #9077
# [[3 2 4]
#  [0 5 7]
#  [8 1 6]]
# Visitando #9078
# [[0 2 4]
#  [3 5 7]
#  [8 1 6]]
# [[3 2 4]
#  [5 0 7]
#  [8 1 6]]
# Visitando #9079
# [[3 0 4]
#  [5 2 7]
#  [8 1 6]]
# [[3 2 4]
#  [5 1 7]
#  [8 0 6]]
# [[3 2 4]
#  [5 7 0]
#  [8 1 6]]
# Visitando #9080
# [[3 2 0]
#  [5 7 4]
#  [8 1 6]]
# [[3 2 4]
#  [5 7 6]
#  [8 1 0]]
# Visitando #9081
# [[3 2 4]
#  [5 7 6]
#  [8 0 1]]
# Visitando #9082
# [[3 2 4]
#  [5 0 6]
#  [8 7 1]]
# [[3 2 4]
#  [5 7 6]
#  [0 8 1]]
# Visitando #9083
# [[3 2 4]
#  [0 7 6]
#  [5 8 1]]
# Visitando #9084
# [[0 2 4]
#  [3 7 6]
#  [5 8 1]]
# [[3 2 4]
#  [7 0 6]
#  [5 8 1]]
# Visitando #9085
# [[3 0 4]
#  [7 2 6]
#  [5 8 1]]
# [[3 2 4]
#  [7 8 6]
#  [5 0 1]]
# [[3 2 4]
#  [7 6 0]
#  [5 8 1]]
# Visitando #9086
# [[3 2 0]
#  [7 6 4]
#  [5 8 1]]
# [[3 2 4]
#  [7 6 1]
#  [5 8 0]]
# Visitando #9087
# [[3 2 4]
#  [7 6 1]
#  [5 0 8]]
# Visitando #9088
# [[3 2 4]
#  [7 0 1]
#  [5 6 8]]
# [[3 2 4]
#  [7 6 1]
#  [0 5 8]]
# Visitando #9089
# [[3 2 4]
#  [0 6 1]
#  [7 5 8]]
# Visitando #9090
# [[0 2 4]
#  [3 6 1]
#  [7 5 8]]
# Visitando #9091
# [[2 0 4]
#  [3 6 1]
#  [7 5 8]]
# Visitando #9092
# [[2 6 4]
#  [3 0 1]
#  [7 5 8]]
# [[2 4 0]
#  [3 6 1]
#  [7 5 8]]
# Visitando #9093
# [[2 4 1]
#  [3 6 0]
#  [7 5 8]]
# Visitando #9094
# [[2 4 1]
#  [3 6 8]
#  [7 5 0]]
# [[2 4 1]
#  [3 0 6]
#  [7 5 8]]
# Visitando #9095
# [[2 0 1]
#  [3 4 6]
#  [7 5 8]]
# [[2 4 1]
#  [3 5 6]
#  [7 0 8]]
# [[2 4 1]
#  [0 3 6]
#  [7 5 8]]
# Visitando #9096
# [[0 4 1]
#  [2 3 6]
#  [7 5 8]]
# [[2 4 1]
#  [7 3 6]
#  [0 5 8]]
# Visitando #9097
# [[2 4 1]
#  [7 3 6]
#  [5 0 8]]
# Visitando #9098
# [[2 4 1]
#  [7 0 6]
#  [5 3 8]]
# [[2 4 1]
#  [7 3 6]
#  [5 8 0]]
# Visitando #9099
# [[2 4 1]
#  [7 3 0]
#  [5 8 6]]
# Visitando #9100
# [[2 4 0]
#  [7 3 1]
#  [5 8 6]]
# [[2 4 1]
#  [7 0 3]
#  [5 8 6]]
# Visitando #9101
# [[2 0 1]
#  [7 4 3]
#  [5 8 6]]
# [[2 4 1]
#  [7 8 3]
#  [5 0 6]]
# [[2 4 1]
#  [0 7 3]
#  [5 8 6]]
# Visitando #9102
# [[0 4 1]
#  [2 7 3]
#  [5 8 6]]
# [[2 4 1]
#  [5 7 3]
#  [0 8 6]]
# Visitando #9103
# [[2 4 1]
#  [5 7 3]
#  [8 0 6]]
# Visitando #9104
# [[2 4 1]
#  [5 0 3]
#  [8 7 6]]
# [[2 4 1]
#  [5 7 3]
#  [8 6 0]]
# Visitando #9105
# [[2 4 1]
#  [5 7 0]
#  [8 6 3]]
# Visitando #9106
# [[2 4 0]
#  [5 7 1]
#  [8 6 3]]
# [[2 4 1]
#  [5 0 7]
#  [8 6 3]]
# Visitando #9107
# [[2 0 1]
#  [5 4 7]
#  [8 6 3]]
# [[2 4 1]
#  [5 6 7]
#  [8 0 3]]
# [[2 4 1]
#  [0 5 7]
#  [8 6 3]]
# Visitando #9108
# [[0 4 1]
#  [2 5 7]
#  [8 6 3]]
# [[2 4 1]
#  [8 5 7]
#  [0 6 3]]
# Visitando #9109
# [[2 4 1]
#  [8 5 7]
#  [6 0 3]]
# Visitando #9110
# [[2 4 1]
#  [8 0 7]
#  [6 5 3]]
# [[2 4 1]
#  [8 5 7]
#  [6 3 0]]
# Visitando #9111
# [[2 4 1]
#  [8 5 0]
#  [6 3 7]]
# Visitando #9112
# [[2 4 0]
#  [8 5 1]
#  [6 3 7]]
# [[2 4 1]
#  [8 0 5]
#  [6 3 7]]
# Visitando #9113
# [[2 0 1]
#  [8 4 5]
#  [6 3 7]]
# [[2 4 1]
#  [8 3 5]
#  [6 0 7]]
# [[2 4 1]
#  [0 8 5]
#  [6 3 7]]
# Visitando #9114
# [[0 4 1]
#  [2 8 5]
#  [6 3 7]]
# [[2 4 1]
#  [6 8 5]
#  [0 3 7]]
# Visitando #9115
# [[2 4 1]
#  [6 8 5]
#  [3 0 7]]
# Visitando #9116
# [[2 4 1]
#  [6 0 5]
#  [3 8 7]]
# [[2 4 1]
#  [6 8 5]
#  [3 7 0]]
# Visitando #9117
# [[2 4 1]
#  [6 8 0]
#  [3 7 5]]
# Visitando #9118
# [[2 4 0]
#  [6 8 1]
#  [3 7 5]]
# [[2 4 1]
#  [6 0 8]
#  [3 7 5]]
# Visitando #9119
# [[2 0 1]
#  [6 4 8]
#  [3 7 5]]
# [[2 4 1]
#  [6 7 8]
#  [3 0 5]]
# [[2 4 1]
#  [0 6 8]
#  [3 7 5]]
# Visitando #9120
# [[0 4 1]
#  [2 6 8]
#  [3 7 5]]
# [[2 4 1]
#  [3 6 8]
#  [0 7 5]]
# Visitando #9121
# [[2 4 1]
#  [3 6 8]
#  [7 0 5]]
# Visitando #9122
# [[2 4 1]
#  [3 0 8]
#  [7 6 5]]
# [[2 4 1]
#  [3 6 8]
#  [7 5 0]]
# Visitando #9123
# Visitando #9124
# [[2 0 1]
#  [3 4 8]
#  [7 6 5]]
# [[2 4 1]
#  [0 3 8]
#  [7 6 5]]
# [[2 4 1]
#  [3 8 0]
#  [7 6 5]]
# Visitando #9125
# [[2 4 0]
#  [3 8 1]
#  [7 6 5]]
# [[2 4 1]
#  [3 8 5]
#  [7 6 0]]
# Visitando #9126
# [[2 4 1]
#  [3 8 5]
#  [7 0 6]]
# Visitando #9127
# [[2 4 1]
#  [3 0 5]
#  [7 8 6]]
# [[2 4 1]
#  [3 8 5]
#  [0 7 6]]
# Visitando #9128
# [[2 4 1]
#  [0 8 5]
#  [3 7 6]]
# Visitando #9129
# [[0 4 1]
#  [2 8 5]
#  [3 7 6]]
# [[2 4 1]
#  [8 0 5]
#  [3 7 6]]
# Visitando #9130
# [[2 0 1]
#  [8 4 5]
#  [3 7 6]]
# [[2 4 1]
#  [8 7 5]
#  [3 0 6]]
# [[2 4 1]
#  [8 5 0]
#  [3 7 6]]
# Visitando #9131
# [[2 4 0]
#  [8 5 1]
#  [3 7 6]]
# [[2 4 1]
#  [8 5 6]
#  [3 7 0]]
# Visitando #9132
# [[2 4 1]
#  [8 5 6]
#  [3 0 7]]
# Visitando #9133
# [[2 4 1]
#  [8 0 6]
#  [3 5 7]]
# [[2 4 1]
#  [8 5 6]
#  [0 3 7]]
# Visitando #9134
# [[2 4 1]
#  [0 5 6]
#  [8 3 7]]
# Visitando #9135
# [[0 4 1]
#  [2 5 6]
#  [8 3 7]]
# [[2 4 1]
#  [5 0 6]
#  [8 3 7]]
# Visitando #9136
# [[2 0 1]
#  [5 4 6]
#  [8 3 7]]
# [[2 4 1]
#  [5 3 6]
#  [8 0 7]]
# [[2 4 1]
#  [5 6 0]
#  [8 3 7]]
# Visitando #9137
# [[2 4 0]
#  [5 6 1]
#  [8 3 7]]
# [[2 4 1]
#  [5 6 7]
#  [8 3 0]]
# Visitando #9138
# [[2 4 1]
#  [5 6 7]
#  [8 0 3]]
# Visitando #9139
# [[2 4 1]
#  [5 6 7]
#  [0 8 3]]
# Visitando #9140
# [[2 4 1]
#  [0 6 7]
#  [5 8 3]]
# Visitando #9141
# [[0 4 1]
#  [2 6 7]
#  [5 8 3]]
# [[2 4 1]
#  [6 0 7]
#  [5 8 3]]
# Visitando #9142
# [[2 0 1]
#  [6 4 7]
#  [5 8 3]]
# [[2 4 1]
#  [6 8 7]
#  [5 0 3]]
# [[2 4 1]
#  [6 7 0]
#  [5 8 3]]
# Visitando #9143
# [[2 4 0]
#  [6 7 1]
#  [5 8 3]]
# [[2 4 1]
#  [6 7 3]
#  [5 8 0]]
# Visitando #9144
# [[2 4 1]
#  [6 7 3]
#  [5 0 8]]
# Visitando #9145
# [[2 4 1]
#  [6 0 3]
#  [5 7 8]]
# [[2 4 1]
#  [6 7 3]
#  [0 5 8]]
# Visitando #9146
# [[2 4 1]
#  [0 7 3]
#  [6 5 8]]
# Visitando #9147
# [[0 4 1]
#  [2 7 3]
#  [6 5 8]]
# [[2 4 1]
#  [7 0 3]
#  [6 5 8]]
# Visitando #9148
# [[2 0 1]
#  [7 4 3]
#  [6 5 8]]
# [[2 4 1]
#  [7 5 3]
#  [6 0 8]]
# [[2 4 1]
#  [7 3 0]
#  [6 5 8]]
# Visitando #9149
# [[2 4 0]
#  [7 3 1]
#  [6 5 8]]
# [[2 4 1]
#  [7 3 8]
#  [6 5 0]]
# Visitando #9150
# [[2 4 1]
#  [7 3 8]
#  [6 0 5]]
# Visitando #9151
# [[2 4 1]
#  [7 0 8]
#  [6 3 5]]
# [[2 4 1]
#  [7 3 8]
#  [0 6 5]]
# Visitando #9152
# [[2 4 1]
#  [0 3 8]
#  [7 6 5]]
# Visitando #9153
# [[0 4 1]
#  [2 3 8]
#  [7 6 5]]
# Visitando #9154
# [[4 0 1]
#  [2 3 8]
#  [7 6 5]]
# Visitando #9155
# [[4 1 0]
#  [2 3 8]
#  [7 6 5]]
# Visitando #9156
# [[4 1 8]
#  [2 3 0]
#  [7 6 5]]
# Visitando #9157
# [[4 1 8]
#  [2 3 5]
#  [7 6 0]]
# [[4 1 8]
#  [2 0 3]
#  [7 6 5]]
# Visitando #9158
# [[4 0 8]
#  [2 1 3]
#  [7 6 5]]
# [[4 1 8]
#  [2 6 3]
#  [7 0 5]]
# [[4 1 8]
#  [0 2 3]
#  [7 6 5]]
# Visitando #9159
# [[0 1 8]
#  [4 2 3]
#  [7 6 5]]
# [[4 1 8]
#  [7 2 3]
#  [0 6 5]]
# Visitando #9160
# [[4 1 8]
#  [7 2 3]
#  [6 0 5]]
# Visitando #9161
# [[4 1 8]
#  [7 2 3]
#  [6 5 0]]
# Visitando #9162
# [[4 1 8]
#  [7 2 0]
#  [6 5 3]]
# Visitando #9163
# [[4 1 0]
#  [7 2 8]
#  [6 5 3]]
# [[4 1 8]
#  [7 0 2]
#  [6 5 3]]
# Visitando #9164
# [[4 0 8]
#  [7 1 2]
#  [6 5 3]]
# [[4 1 8]
#  [7 5 2]
#  [6 0 3]]
# [[4 1 8]
#  [0 7 2]
#  [6 5 3]]
# Visitando #9165
# [[0 1 8]
#  [4 7 2]
#  [6 5 3]]
# [[4 1 8]
#  [6 7 2]
#  [0 5 3]]
# Visitando #9166
# [[4 1 8]
#  [6 7 2]
#  [5 0 3]]
# Visitando #9167
# [[4 1 8]
#  [6 0 2]
#  [5 7 3]]
# [[4 1 8]
#  [6 7 2]
#  [5 3 0]]
# Visitando #9168
# [[4 1 8]
#  [6 7 0]
#  [5 3 2]]
# Visitando #9169
# [[4 1 0]
#  [6 7 8]
#  [5 3 2]]
# [[4 1 8]
#  [6 0 7]
#  [5 3 2]]
# Visitando #9170
# [[4 0 8]
#  [6 1 7]
#  [5 3 2]]
# [[4 1 8]
#  [6 3 7]
#  [5 0 2]]
# [[4 1 8]
#  [0 6 7]
#  [5 3 2]]
# Visitando #9171
# [[0 1 8]
#  [4 6 7]
#  [5 3 2]]
# [[4 1 8]
#  [5 6 7]
#  [0 3 2]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 24
#      21 dfs_solver = DepthFirstSearch(problema)
#      23 # Resolvendo o problema com DFS
# ---> 24 solucao_encontrada_dfs, estados_visitados_dfs, cont_estados_dfs = dfs_solver.busca(start, target)
#      26 # Imprimindo os resultados do DFS
#      27 if solucao_encontrada_dfs:
#
# Cell In[13], line 55, in DepthFirstSearch.busca(self, inicio, fim)
#      53 novos_estados = self.problema.expande_estados(atual)
#      54 for i in novos_estados:
# ---> 55     if not self._verifica_visitado(i, estados_visitados):
#      56         print(i)
#      57         pilha.put(i)
#
# Cell In[13], line 22, in DepthFirstSearch._verifica_visitado(self, estado, estados_visitados)
#      13 '''
#      14 Verifica se 'estado' está na lista de estados visitados
#      15 Args:
#    (...)
#      19     - booleano dizendo se o estado foi visitado ou não
#      20 '''
#      21 for i in estados_visitados:
# ---> 22     if self.problema.verifica_estados(i, estado):
#      23         return True
#      24 return False
#
# Cell In[11], line 38, in SlidingPuzzle.verifica_estados(self, atual, objetivo)
#      36 flag = True
#      37 for i in range(self.num_blocos):
# ---> 38     for j in range(self.num_blocos):
#      39         if atual[i, j] != objetivo[i, j]:
#      40             flag = False
#
# KeyboardInterrupt:

# %% [markdown]
# 2. Desenhe no papel, a árvore dos seguintes grafos e diga qual o caminho BFS e DFS saindo de O e indo para X.

# %% [markdown]
# A)

# %% [markdown]
# <img src="images/GRAFO_A.png" width="250" align="center">

# %% [markdown]
# B)

# %% [markdown]
# <img src="images/GRAFO_B.png" width="250" align="center">
